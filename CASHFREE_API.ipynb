# %%
import jwt
import pandas as pd
import datetime
import requests
import urllib.request, urllib.parse, urllib.error
import json
import ssl

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = "https://cac-api.cashfree.com/cac/v1/authorize"
headers1 = {'X-Client-Id':'CF76905EK356NX699EAME6','X-Client-Secret':'0eaaeb50e7191f78af42a2b7c16644bc72039176'}
urllistva = "https://cac-api.cashfree.com/cac/v1/allVA"
headers2 = {'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],'Content-Type':'application/json'}
data1 = requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']
i=0
list_data=[]
sum_=[]
paras ={'endDate': '20211119', 'startDate': '20210101'} #YMD
# while i < len(data1):
for i in range(len(data1)):
    urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
    datapayments = requests.get(urlpayment,params=paras, headers=headers2).json()
    try:
        parse_data= datapayments['data']['payments']
        print("i is :",i)
#         val=datapayments['data']['payments']['vAccountId']
        print('V_A/C is:',val)
    except:
        pass
    df = pd.json_normalize(parse_data)
    df['vAccountId'] = data1[i]['vAccountId']
    df['name'] = data1[i]['name']
#     print('********************parse_data *********************',parse_data ,len(datapayments['data']['payments']))
    list_data.append(df)
#     print(df)
    
#     try:
#         lastReturnId= datapayments['data']['lastReturnId']
# #         print('lastReturnId is :', lastReturnId,"for i",i)
#     except:
#         pass
    try:
        while True:
            lastReturnId= datapayments['data']['lastReturnId']
            print('lastReturnId is' ,lastReturnId)
            paras ={'endDate': '20211119', 'startDate': '20210101', 'lastReturnId': int(lastReturnId)}
#             headers2 = {'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],'Content-Type':'application/json'}
#             urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
            datapayments = requests.get(urlpayment,params=paras, headers=headers2).json()
#             parse_data= datapayments['data']['payments']
            print('datapayments is' ,datapayments)
            print('V_A/C is:', datapayments['data']['payments']['vAccountId'])
            df = pd.json_normalize(parse_data)
            df['vAccountId'] = data1[i]['vAccountId']
            df['name'] = data1[i]['name']
            
            list_data.append(df)
            print('Inside While')
    except:
        pass
list_data = pd.concat(list_data)
print('********** COMPLEATED **********')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-c91a17211bd9> in <module>
#      14 headers1 = {'X-Client-Id':'CF76905EK356NX699EAME6','X-Client-Secret':'0eaaeb50e7191f78af42a2b7c16644bc72039176'}
#      15 urllistva = "https://cac-api.cashfree.com/cac/v1/allVA"
# ---> 16 headers2 = {'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],'Content-Type':'application/json'}
#      17 data1 = requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']
#      18 i=0
#
# KeyError: 'data'

# %%
list_data
# Out:
#     vAccountId           name  referenceId    amount  \
# 0        22134      H K FOODS   52713625.0      1.00
# 0        22132       ND Foods   52713515.0      1.00
# 0        22131    KRIVA FOODS   52713466.0      1.00
# 1        22131    KRIVA FOODS   52446667.0     21.72
# 2        22131    KRIVA FOODS   52280472.0  14004.44
# ..         ...            ...          ...       ...
# 37  TMPFRS18ND  Anshika Singh   20737776.0      1.00
# 0   TMPFRRSQAM     EAVY FOODS   20737597.0      1.00
# 0    TMPFRLNDL   RAJEEV ARORA   20737168.0      1.00
# 0   TMPFRINDGB     Gaurav Rao   20736908.0      1.00
# 0   TMPFRHSRPB  SATYAM NAGPAL   20736311.0      1.00
#
#                           utr  creditRefNo  remitterAccount  \
# 0                131212698810  00122164740     022405500543
# 0                131212696818  00122164647     022405500543
# 0                131212694020  00122164560     022405500543
# 1            N309211703603306  00121807097   50200045675140
# ...

# %%
import jwt
import pandas as pd
import datetime
import requests
import urllib.request, urllib.parse, urllib.error
import json
import ssl

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = "https://cac-api.cashfree.com/cac/v1/authorize"
headers1 = {'X-Client-Id':'CF76905EK356NX699EAME6','X-Client-Secret':'0eaaeb50e7191f78af42a2b7c16644bc72039176'}
urllistva = "https://cac-api.cashfree.com/cac/v1/allVA"
headers2 = {'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],'Content-Type':'application/json'}
data1 = requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']
i=0
list_data=[]
sum_=[]
paras ={'endDate': '20211101', 'startDate': '20211001'} #YMD
# while i < len(data1):
for i in range(len(data1)):
    urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
    datapayments = requests.get(urlpayment,params=paras, headers=headers2).json()
    try:
        parse_data= datapayments['data']['payments']
#         parse_data= datapayments['data']['lastReturnId']
        df = pd.json_normalize(parse_data)
        df['vAccountId'] = data1[i]['vAccountId']
        df['name'] = data1[i]['name']
    except:
        pass
    list_data.append(df)
    print(len(datapayments['data']['payments']),' for i' ,i)
    
#     if datapayments['message']=='No Payments to be retrieved':
#         continue
#     else:
#         try:
#             numofpayemnts = len(datapayments['data']['payments'])
#             sum_.append(numofpayemnts)
#         except:
#             pass
#         print(numofpayemnts)
    
print(sum(sum_))

list_data = pd.concat(list_data)
print('********** COMPLEATED **********')
# Out:
# 0  for i 0
# 0  for i 1
# 0  for i 2
# 0  for i 3
# 0  for i 4
# 0  for i 5
# 0  for i 6
# 0  for i 7
# 0  for i 8
# 1  for i 9
# 0  for i 10
# 0  for i 11
# 7  for i 12
# 0  for i 13
# 0  for i 14
# 0  for i 15
# 0  for i 16
# 0  for i 17
# 0  for i 18
# 59  for i 19
# 15  for i 20
# 59  for i 21
# 61  for i 22
# 0  for i 23
# 37  for i 24
# 43  for i 25
# 39  for i 26
# 33  for i 27
# 53  for i 28
# 65  for i 29
# 60  for i 30
# 25  for i 31
# 0  for i 32
# 25  for i 33
# 63  for i 34
# 30  for i 35
# 0  for i 36
# 90  for i 37
# 32  for i 38
# 55  for i 39
# 23  for i 40
# 2  for i 41
# 40  for i 42
# 1  for i 43
# 42  for i 44
# 19  for i 45
# 60  for i 46
# 20  for i 47
# 58  for i 48
# 71  for i 49
# 47  for i 50
# 60  for i 51
# 0  for i 52
# 0  for i 53
# 0  for i 54
# 0  for i 55
# 0  for i 56
# 0  for i 57
# 0  for i 58
# 0  for i 59
# 0  for i 60
# 0  for i 61
# 0  for i 62
# 0  for i 63
# 8  for i 64
# 0  for i 65
# 4  for i 66
# 0  for i 67
# 0  for i 68
# 0  for i 69
# ...

# %%
list_data
# datapayments
# 7567
# Out:
#     vAccountId                         name  referenceId    amount  \
# 0        22126                    True Blue   51579313.0    138.30
# 0        22123                Anubhav Kumar   51470360.0  19984.18
# 1        22123                Anubhav Kumar   51468017.0   3251.51
# 2        22123                Anubhav Kumar   50724935.0   1531.86
# 3        22123                Anubhav Kumar   50724897.0  13718.29
# ..         ...                          ...          ...       ...
# 17  TMPPLNITFB  Crave Foods Tipping Mr Pink   49363953.0   6025.95
# 18  TMPPLNITFB  Crave Foods Tipping Mr Pink   49246192.0  26929.10
# 19  TMPPLNITFB  Crave Foods Tipping Mr Pink   49131054.0  10981.94
# 20  TMPPLNITFB  Crave Foods Tipping Mr Pink   49030773.0  11272.18
# 21  TMPPLNITFB  Crave Foods Tipping Mr Pink   48695437.0  10094.67
#
#                  utr  creditRefNo remitterAccount           remitterName  \
# 0   CITIN21261066593  00120447511      0711872078    ZOMATOLIMITED-NODAL
# ...

# %%
list_data.to_excel('CASHFREE_API.xlsx', index=False)

# %%
import jwt
import datetime
import requests
import urllib.request, urllib.parse, urllib.error
import json
import ssl

# ctx = ssl.create_default_context()
# ctx.check_hostname = False
# ctx.verify_mode = ssl.CERT_NONE

url = "https://cac-api.cashfree.com/cac/v1/authorize"

headers1 = {
'X-Client-Id':'CF76905EK356NX699EAME6',
'X-Client-Secret':'0eaaeb50e7191f78af42a2b7c16644bc72039176'
}
# print(requests.post(url,headers=headers1).json())
#
urllistva = "https://cac-api.cashfree.com/cac/v1/allVA"
#
headers2 = {
'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],
'Content-Type':'application/json'
}
# headers2 = {
# 'Authorization':'Bearer de9JCN4MzUIJiOicGbhJCLiQ1VKJiOiAXe0Jye.L503NyYjNxYjNzYTM6ICc4VmIsISM0EjLxcTMuEjNx4iMyEjI6ICcpJCLwojIrNWZoNUZyVHdh52ZpNnIscjNyYTM2YzM2EjOiQXYpJCLiYTRNFUR5kjNY5kN1MzSFVDM5YzNGNkI6ICZJRnbllGbjJye.MxnzkZFIBStO-yyNbEo0Q5gGk_PsW25fC5vC1dDDG6cJgko7TNcPbMFdNGOui_35vg',
# 'Content-Type':'application/json'
# }
# paras = {"startDate":'2020-01-01' ,"endDate":'2021-11-15'}
# print(requests.get(urllistva,headers=headers2).json())
data = requests.get(urllistva,headers=headers2).json()
data1 = requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']
print(len(requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']))
i=0
# urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
# print(requests.get(urlpayment,headers=headers2).json()['data']['payments'][0]['referenceId'])
data_1=[]
data_2=[]
data_3=[]
data_4=[]
data_5=[]
data_6=[]
data_7=[]
data_8=[]
data_9=[]
# data10=[]
# data11=[]
# data12=[]
while i < (len(data1)-1):
    # print(data1[i]['vAccountId']+"-"+data1[i]['name'])
#     print(data1[i]['vAccountId'])
    urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
#     print(i)
    i=i+1
    datapayments = requests.get(urlpayment,headers=headers2).json()
    if datapayments['message']=='No Payments to be retrieved':
        continue
    else:
        numofpayemnts = len(datapayments['data']['payments'])
#         print(numofpayemnts)
        j=0
        while j < numofpayemnts:
#             try:
#                 print(j)
#             print(data1[i]['vAccountId'])
                data_1.append(data1[i]['vAccountId'])
#             print(datapayments['data']['payments'][j]['referenceId'])
#             except:
#                 pass
                data_2.append(datapayments['data']['payments'][j]['referenceId'])
    #             print(datapayments['data']['payments'][j]['amount'])
                data_3.append(datapayments['data']['payments'][j]['amount'])
    #             print(datapayments['data']['payments'][j]['utr'])
                data_4.append(datapayments['data']['payments'][j]['utr'])
    #             print(datapayments['data']['payments'][j]['remitterName'])
                data_5.append(datapayments['data']['payments'][j]['remitterName'])
    #             print(datapayments['data']['payments'][j]['paymentTime'])
                data_6.append(datapayments['data']['payments'][j]['paymentTime'])
    #             print(datapayments['data']['payments'][j]['isSettled'])
                data_7.append(datapayments['data']['payments'][j]['isSettled'])
    #             print(datapayments['data']['payments'][j]['remitterAccount'])
                data_8.append(datapayments['data']['payments'][j]['remitterAccount'])
    #             print(datapayments['data']['payments'][j]['settlementUtr'])
                data_9.append(datapayments['data']['payments'][j]['settlementUtr'])
                j=j+1
#                 print('***********************************************')
#             lst = [['fav', 11], ['tutor', 22], ['coding', 33], ['skills', 44]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-8e2c62d6777a> in <module>
#      21 #
#      22 headers2 = {
# ---> 23 'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],
#      24 'Content-Type':'application/json'
#      25 }
#
# KeyError: 'data'

# %%
# data['data']['vAccounts']

# %%
dic = { 'vAccountId':       data_1,
        'referenceId':      data_2,
        'amount':           data_3,
        'utr':              data_4,
        'remitterName':     data_5,
        'paymentTime':      data_6,
        'isSettled':        data_7,
        'remitterAccount':  data_8,
        'settlementUtr' :   data_9}

# %%
import pandas as pd
df1 = pd.DataFrame(dic)

# %%
df1
# Out:
#      vAccountId  referenceId    amount               utr  \
# 0         22133     52713625      1.00      131212698810
# 1         22131     53878152   5451.00      132414746287
# 2         22131     53776091   2726.00      132313298949
# 3         22131     53718306  36168.26  CITIN21273068342
# 4         22131     53688581    480.00      132210060405
# ...         ...          ...       ...               ...
# 7561  NAVEEN001     28126420  24216.53  CITIN21144073209
# 7562  NAVEEN001     27698524  18981.82  CITIN21143112784
# 7563  NAVEEN001     27585665   1252.51  CITIN21142616072
# 7564  NAVEEN001     27585640   6667.23  CITIN21142613125
# 7565  NAVEEN001     27581155    133.88  CITIN21142558227
#
#                       remitterName          paymentTime  isSettled  \
# 0                         BharatPe  2021-11-08 12:31:31          1
# 1                         BharatPe  2021-11-20 02:41:46          1
# 2                         BharatPe  2021-11-19 03:01:14          1
# ...

# %%
# df1.to_excel('CASHFREE_API.xlsx', index=False)

# %%
# import pandas as pd
# import gspread
# import gspread_dataframe as gd
# from gspread_dataframe import set_with_dataframe


# gc = gspread.service_account(filename='universalsolder.json')
# # sh = gc.open_by_key('1hwqYXSi7vMHvHHZcJ2ru3T8sxkpiAy1Tlxry_FgGDzk')#sales_summary
# sh = gc.open_by_key('1ozb_w0pfHMsAXaT2ByPmfMfY6F5r0y9MvOTo94Vpi6E')#sales_page

# worksheet = sh.get_worksheet(0) #-> 0 - first sheet, 1 - second sheet etc. 
# set_with_dataframe(worksheet, df)

# %%
# import jwt
# import datetime
# import requests
# import urllib.request, urllib.parse, urllib.error
# import json
# import ssl

# # ctx = ssl.create_default_context()
# # ctx.check_hostname = False
# # ctx.verify_mode = ssl.CERT_NONE

# url = "https://cac-api.cashfree.com/cac/v1/authorize"

# headers1 = {
# 'X-Client-Id':'CF76905EK356NX699EAME6',
# 'X-Client-Secret':'0eaaeb50e7191f78af42a2b7c16644bc72039176'
# }
# # print(requests.post(url,headers=headers1).json())
# #
# urllistva = "https://cac-api.cashfree.com/cac/v1/allVA"
# #
# headers2 = {
# 'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],
# 'Content-Type':'application/json'
# }
# # headers2 = {
# # 'Authorization':'Bearer de9JCN4MzUIJiOicGbhJCLiQ1VKJiOiAXe0Jye.L503NyYjNxYjNzYTM6ICc4VmIsISM0EjLxcTMuEjNx4iMyEjI6ICcpJCLwojIrNWZoNUZyVHdh52ZpNnIscjNyYTM2YzM2EjOiQXYpJCLiYTRNFUR5kjNY5kN1MzSFVDM5YzNGNkI6ICZJRnbllGbjJye.MxnzkZFIBStO-yyNbEo0Q5gGk_PsW25fC5vC1dDDG6cJgko7TNcPbMFdNGOui_35vg',
# # 'Content-Type':'application/json'
# # }
# # print(requests.get(urllistva,headers=headers2).json())
# data1 = requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']

# %%
# file = response['data']
df2 = pd.json_normalize(data1)

# appended_data = pd.concat(appended_data)

# %%
df2
# Out:
#     vAccountId virtualAccountNumber                              name  \
# 0        22135    80808080660722135                          DOONITES
# 1        22134    80808080660722134                         H K FOODS
# 2        22133    80808080660722133                       RN VENTURES
# 3        22132    80808080660722132                          ND Foods
# 4        22131    80808080660722131                       KRIVA FOODS
# ..         ...                  ...                               ...
# 91  TMPPLLWRPB   90936607TMPPLLWRPB  Bernhardiner Zod Tipping Mr Pink
# 92  TMPPLCHTDL   90936607TMPPLCHTDL          Unifrost Tipping Mr Pink
# 93    TMPPLNIT     90936607TMPPLNIT       Crave Foods Tipping Mr Pink
# 94  TMPPLNITFB   90936607TMPPLNITFB       Crave Foods Tipping Mr Pink
# 95   NAVEEN001    90936607NAVEEN001                      Naveen Kumar
#
#          phone                               email remitterAccount  \
# 0   9999375639   babul.anand@burgersinghonline.com
# ...

# %%
Final_DF = pd.merge(df1,  df2,  on ='vAccountId',  how ='inner')
name_column = Final_DF.pop('name')
Final_DF.insert(1, 'name', name_column)

# %%
# Final_DF.drop(columns=['phone','email','maxAmount','ifsc'])
Final_DF
# Out:
#      vAccountId          name  referenceId   amount               utr  \
# 0         22133   RN VENTURES     52713625     1.00      131212698810
# 1         22131   KRIVA FOODS     53688581   480.00      132210060405
# 2         22131   KRIVA FOODS     53676513  2708.00      132211912483
# 3         22131   KRIVA FOODS     53590212  3283.00      132110418070
# 4         22131   KRIVA FOODS     53588889  4343.00      132108041742
# ...         ...           ...          ...      ...               ...
# 7504  NAVEEN001  Naveen Kumar     27585665  1252.51  CITIN21142616072
# 7505  NAVEEN001  Naveen Kumar     27585640  6667.23  CITIN21142613125
# 7506  NAVEEN001  Naveen Kumar     27581155   133.88  CITIN21142558227
# 7507  NAVEEN001  Naveen Kumar     27581142   508.93  CITIN21142556706
# 7508  NAVEEN001  Naveen Kumar     27575806  2976.84  SIN31702R3243766
#
#                       remitterName          paymentTime  isSettled  \
# ...

# %%
# import pandas as pd
import gspread
import gspread_dataframe as gd
from gspread_dataframe import set_with_dataframe


gc = gspread.service_account(filename='universalsolder.json')
# sh = gc.open_by_key('1hwqYXSi7vMHvHHZcJ2ru3T8sxkpiAy1Tlxry_FgGDzk')#sales_summary
sh = gc.open_by_key('1CxtQMvpt3XzixqSFn1C2ugAY3Eyh-TSMsn7hKcEGxHQ')#Name

worksheet = sh.get_worksheet(0) #-> 0 - first sheet, 1 - second sheet etc. 
set_with_dataframe(worksheet, Final_DF)
print("******************* File Has Been Sent To Google Sheet *******************")
# Out:
# ******************* File Has Been Sent To Google Sheet *******************

# %%
import sys
print(sys.maxsize)
# 9223372036854775807

# %%
import jwt
import datetime
import requests
import urllib.request, urllib.parse, urllib.error
import json
import ssl

# ctx = ssl.create_default_context()
# ctx.check_hostname = False
# ctx.verify_mode = ssl.CERT_NONE

url = "https://cac-api.cashfree.com/cac/v1/authorize"

headers1 = {
'X-Client-Id':'CF76905EK356NX699EAME6',
'X-Client-Secret':'0eaaeb50e7191f78af42a2b7c16644bc72039176'
}
# print(requests.post(url,headers=headers1).json())
#
urllistva = "https://cac-api.cashfree.com/cac/v1/allVA"
#
headers2 = {
'Authorization':'Bearer '+requests.post(url,headers=headers1).json()["data"]["token"],
'Content-Type':'application/json'
}
# headers2 = {
# 'Authorization':'Bearer de9JCN4MzUIJiOicGbhJCLiQ1VKJiOiAXe0Jye.L503NyYjNxYjNzYTM6ICc4VmIsISM0EjLxcTMuEjNx4iMyEjI6ICcpJCLwojIrNWZoNUZyVHdh52ZpNnIscjNyYTM2YzM2EjOiQXYpJCLiYTRNFUR5kjNY5kN1MzSFVDM5YzNGNkI6ICZJRnbllGbjJye.MxnzkZFIBStO-yyNbEo0Q5gGk_PsW25fC5vC1dDDG6cJgko7TNcPbMFdNGOui_35vg',
# 'Content-Type':'application/json'
# }
# paras = {"startDate":'2020-01-01' ,"endDate":'2021-11-15'}
# print(requests.get(urllistva,headers=headers2).json())
data = requests.get(urllistva,headers=headers2).json()
data1 = requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']
print(len(requests.get(urllistva,headers=headers2).json()["data"]['vAccounts']))
i=0
# urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
# print(requests.get(urlpayment,headers=headers2).json()['data']['payments'][0]['referenceId'])
data_1=[]
data_2=[]
data_3=[]
data_4=[]
data_5=[]
data_6=[]
data_7=[]
data_8=[]
data_9=[]
# data10=[]
# data11=[]
# data12=[]
while i < len(data1):
    # print(data1[i]['vAccountId']+"-"+data1[i]['name'])
#     print(data1[i]['vAccountId'])
    urlpayment = 'https://cac-api.cashfree.com/cac/v1/payments/'+data1[i]['vAccountId']
#     print(i)
    i=i+1
    datapayments = requests.get(urlpayment,headers=headers2).json()
    if datapayments['message']=='No Payments to be retrieved':
        continue
    else:
        numofpayemnts = len(datapayments['data']['payments'])
#         print(numofpayemnts)
        j=0
        while j < numofpayemnts:
#             print(j)
#             print(data1[i]['vAccountId'])
            try:
                data_1.append(data1[i]['vAccountId'])
            except:   
                pass
    #             print(datapayments['data']['payments'][j]['referenceId'])
            data_2.append(datapayments['data']['payments'][j]['referenceId'])
#             print(datapayments['data']['payments'][j]['amount'])
            data_3.append(datapayments['data']['payments'][j]['amount'])
#             print(datapayments['data']['payments'][j]['utr'])
            data_4.append(datapayments['data']['payments'][j]['utr'])
#             print(datapayments['data']['payments'][j]['remitterName'])
            data_5.append(datapayments['data']['payments'][j]['remitterName'])
#             print(datapayments['data']['payments'][j]['paymentTime'])
            data_6.append(datapayments['data']['payments'][j]['paymentTime'])
#             print(datapayments['data']['payments'][j]['isSettled'])
            data_7.append(datapayments['data']['payments'][j]['isSettled'])
#             print(datapayments['data']['payments'][j]['remitterAccount'])
            data_8.append(datapayments['data']['payments'][j]['remitterAccount'])
#             print(datapayments['data']['payments'][j]['settlementUtr'])
            data_9.append(datapayments['data']['payments'][j]['settlementUtr'])
            j=j+1
           
#             print('***********************************************')
#             lst = [['fav', 11], ['tutor', 22], ['coding', 33], ['skills', 44]]
            
dic = { 'vAccountId':       data_1,
        'referenceId':      data_2,
        'amount':           data_3,
        'utr':              data_4,
        'remitterName':     data_5,
        'paymentTime':      data_6,
        'isSettled':        data_7,
        'remitterAccount':  data_8,
        'settlementUtr' :   data_9}
import pandas as pd
df1 = pd.DataFrame(dic)
df2 = pd.json_normalize(data1)
Final_DF = pd.merge(df1,  df2,  on ='vAccountId',  how ='inner')
name_column = Final_DF.pop('name')
Final_DF.insert(1, 'name', name_column)
print("******************* File Has Been Sent To Google Sheet *******************")


# import gspread
# import gspread_dataframe as gd
# from gspread_dataframe import set_with_dataframe
# gc = gspread.service_account(filename='universalsolder.json')
# sh = gc.open_by_key('1medgDQDcWxr7FQ0fA_w5U4nzONT786mSaeFEySi7NLc')#Name
# worksheet = sh.get_worksheet(0) #-> 0 - first sheet, 1 - second sheet etc. 
# set_with_dataframe(worksheet, Final_DF)
print("******************* File Has Been Sent To Google Sheet *******************")
# Out:
# 96
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3e075374c58f> in <module>
#     100         'settlementUtr' :   data_9}
#     101 import pandas as pd
# --> 102 df1 = pd.DataFrame(dic)
#     103 df2 = pd.json_normalize(data1)
#     104 Final_DF = pd.merge(df1,  df2,  on ='vAccountId',  how ='inner')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
# ...
