# %%
from time import gmtime, strftime
from datetime import datetime
import datetime
import requests
import pandas as pd
import json
import jwt
import time
import ssl

from datetime import datetime
from pytz import timezone
# format = "%Y-%m-%d %H:%M:%S %Z%z"
format = "%Y-%m-%d"
# Current time in UTC
now_utc = datetime.now(timezone('UTC'))
# print(now_utc.strftime(format))
# Convert to Asia/Kolkata time zone
now_asia = now_utc.astimezone(timezone('Asia/Kolkata'))
Today = str(now_asia.strftime(format))

# now = datetime.now()
# Time = now.strftime("%a %b %d %Y %I:%M GMT(%Z)\n")
# Time = strftime("%a %b %d %Y %I:%M:%S GMT(%Z)\n")
# tokenCreationTime = str(datetime.now().time())
# import time
print("******************************")
print("Today Date is :",Today)
print("******************************")
# URL = "https://api.ristaapps.com/v1/inventory/item/activity"
# URL = "https://api.ristaapps.com/v1/items/soldout"
# URL = "https://api.ristaapps.com/v1/sales/page"
# URL = "https://api.ristaapps.com/v1"


# URL = "https://api.ristaapps.com/v1/inventory/item/activity"


apiKey = 'e1b9bba5-206f-47a7-9904-633b3d95a8c7'
secretKey = 'mdgGj4sOp5Ly4ed-s2lYFuDrON8nic56L9lJ81nEMmY'

tokenCreationTime = int(round(time.time()))
# print(tokenCreationTime)

payload = {"iss": apiKey, "iat": tokenCreationTime}

token =   jwt.encode(payload, secretKey) 
#*************************************************************************************
# BRANCH_URL = "https://api.ristaapps.com/v1/branch/list"
# head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
# response=requests.get(BRANCH_URL,headers=head).json()
# df = pd.json_normalize(response)
# Branch_Code=[]
# for i in df['branchCode']:
#     Branch_Code.append(str(i))
# print(Branch_Code)
Branch_Code= ['AL1','ASH','CHN','CLJ','CP','CSP',
              'DDT','DK','GC1','GDK','GFP','GN',
              'GTB','HO','IN','IP','JAK','JNK',
              'KK','KN','LN','MJ','MN','MVD',
              'N137','N18','N50','NCR WH','NFC',
              'NIT','PV','RA','RDS','RG','RJN','ROH',
              'RP','S122','S49','S7GGN','S81','S83',
              'S9CHD','SC','SCC','SDR','Sec31FBD','SLK','SP','VK']
#*************************************************************************************    
URL = "https://api.ristaapps.com/v1/inventory/shrinkage/page"

# appended_data.append(data)# loop
# appended_data = pd.concat(appended_data)
appended_data = []
for BC in Branch_Code:
    try:
        print("Working Branch :",BC)
        #run your code
        paras = {"branch": BC, "day":'2021-11-10'}
        head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
        response = requests.get(URL, params=paras, headers=head).json()
        file = response['data']
        df = pd.json_normalize(file)
        appended_data.append(df)# loop
        
#         print(appended_data)
        
    except:
#         print('Erro')
        print("Not Working Branch :",BC)
        pass
# requests.get(URL, params=paras, headers=head).json()
# print(response.text)

# response = requests.get(URL, headers={'x-api-key': apiKey ,'x-api-token': jwt.encode({ "iss": apiKey, "iat": int(round(time.time())) }, secretKey, algorithm="HS256")}, data={ "iss": apiKey, "iat": int(round(time.time()))})
# print(response.json())
# (response).json()
# print(response.text)
# print(response)
appended_data = pd.concat(appended_data)
print('****************** COMPLETE **********************')
    # print(response)
# Out:
# ******************************
# Today Date is : 2021-11-17
# ******************************
# Working Branch : AL1
# Working Branch : ASH
# Working Branch : CHN
# Working Branch : CLJ
# Working Branch : CP
# Working Branch : CSP
# Working Branch : DDT
# Working Branch : DK
# Working Branch : GC1
# Working Branch : GDK
# Working Branch : GFP
# Working Branch : GN
# Working Branch : GTB
# Working Branch : HO
# Working Branch : IN
# Working Branch : IP
# Working Branch : JAK
# Working Branch : JNK
# Working Branch : KK
# Working Branch : KN
# Working Branch : LN
# Working Branch : MJ
# Working Branch : MN
# Working Branch : MVD
# Working Branch : N137
# Working Branch : N18
# Working Branch : N50
# Working Branch : NCR WH
# Working Branch : NFC
# Working Branch : NIT
# Working Branch : PV
# Working Branch : RA
# Working Branch : RDS
# Working Branch : RG
# Working Branch : RJN
# Working Branch : ROH
# Working Branch : RP
# Working Branch : S122
# Working Branch : S49
# Working Branch : S7GGN
# Working Branch : S81
# Working Branch : S83
# Working Branch : S9CHD
# Working Branch : SC
# Working Branch : SCC
# Working Branch : SDR
# Working Branch : Sec31FBD
# Working Branch : SLK
# Working Branch : SP
# Working Branch : VK
# ****************** COMPLETE **********************

# %%
appended_data
# Out:
#   branchCode              branchName shrinkageNumber  \
# 0        AL1                 Alpha 1            9330
# 0        ASH                Ashiyana            9284
# 0        CHN            Channi Jammu            9245
# 0        CLJ             Civil Lines            9248
# 0        DDT              Devrana DT            9253
# 0         DK                  Dwarka            9339
# 0        GC1    Gaur City 1 Gr Noida            9308
# 0        GDK      Gandhidham Kachchh            9266
# 0         GN             Gomti Nagar            9319
# 0        GTB               GTB Nagar            9299
# 1        GTB               GTB Nagar            9304
# 0         IN            Indira Nagar            9265
# 0        JAK              Jakhan DDN            9262
# 0        JNK               Janakpuri            9328
# 0         KK                 Kalkaji            9291
# 0         KN           Krishna Nagar            9317
# 1         KN           Krishna Nagar            9323
# 0         LN            Lajpat Nagar            9298
# 0         MJ        Malviya Nagar JP            9275
# 0         MN           Malviya Nagar            9314
# 0        MVD             Mayur Vihar            9287
# 0       N137        Sector 137 Noida            9286
# 0        N18            Sec 18 Noida            9258
# 0        N50            Sec 50 Noida            9249
# 0        NFC      New Friends Colony            9345
# 0         PV             Palam Vihar            9315
# 0         RA  Ranjit Avenue Amritsar            9289
# 0        RJN               Raj Nagar            9321
# 0        ROH                  Rohini            9336
# 0         RP          Rajendra Place            9272
# 0       S122           Sec 122 Noida            9247
# 0        S49              Sec 49 GGN            9293
# 0      S7GGN               Sec 7 GGN            9269
# 0        S81              Sec 81 FBD            9325
# 0        S83              Sec 83 GGN            9309
# 0      S9CHD               Sec 9 CHD            9211
# 1      S9CHD               Sec 9 CHD            9337
# 0         SC                 Suncity            9290
# 0   Sec31FBD              Sec 31 FBD            9302
# 0        SLK             Sushant Lok            9318
# 0         SP        Shradhanand Peth            9303
# 0         VK             Vasant Kunj            9342
#
#                shrinkageDate shrinkageBusinessDay  totalAmount status  \
# 0  2021-11-11T04:47:57+05:30           2021-11-10       -56.02  Final
# 0  2021-11-11T02:00:18+05:30           2021-11-10      -975.96  Final
# 0  2021-11-10T22:33:24+05:30           2021-11-10      -436.27  Final
# 0  2021-11-10T23:20:01+05:30           2021-11-10      -238.58  Final
...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 1  [{'measuringUnit': 'Piece', 'skuCode': '242', ...
# 0  [{'measuringUnit': 'Kilogram', 'skuCode': '255...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '304', ...
# 0  [{'measuringUnit': 'Kilogram', 'skuCode': '255...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...

# %%
column_= appended_data.columns
COLUMN_NAMES= ['branchName', 'branchCode', 'invoiceNumber', 'invoiceDate',
       'invoiceType', 'chargeAmount', 'grossAmount', 'discountAmount',
       'taxAmount', 'netAmount', 'roundOffAmount', 'tipAmount', 'totalAmount',
       'customerId', 'customerName', 'saleBy', 'channel', 'label', 'status',
       'sessionLabel']
DF = pd.DataFrame(columns=COLUMN_NAMES)

# %%
for column in COLUMN_NAMES:
    if column  in column_:
        value= appended_data[column]
        #         DF.insert(count,column,value)
        DF[column]=value

# %%
from time import gmtime, strftime
from datetime import datetime
import datetime
import requests
import pandas as pd
import json
import jwt
import time
import ssl

from datetime import datetime
from pytz import timezone
format = "%Y-%m-%d"
now_utc = datetime.now(timezone('UTC'))
now_asia = now_utc.astimezone(timezone('Asia/Kolkata'))
Today = str(now_asia.strftime(format))

URL = "https://api.ristaapps.com/v1/inventory/shrinkage/page"
apiKey = 'e1b9bba5-206f-47a7-9904-633b3d95a8c7'
secretKey = 'mdgGj4sOp5Ly4ed-s2lYFuDrON8nic56L9lJ81nEMmY'

tokenCreationTime = int(round(time.time()))
payload = {"iss": apiKey, "iat": tokenCreationTime}
token =   jwt.encode(payload, secretKey) 

paras = {"branch": 'MVD', "day":'2021-11-10'}
head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
response=requests.get(URL,params=paras,headers=head).json()

data=response['data']
#  =data['items']
df = pd.json_normalize(data)

# %%
bc= df['branchName'][0]
data_file =response['data'][0]['items']
df_ = pd.json_normalize(data_file)
df_['branchName']= bc
df_
# Out:
#   measuringUnit skuCode                            itemName  quantity  \
# 0         Piece     290                               Bun 4        -2
# 1         Piece     298  Cheese N Veg Delight Patty - Small        -1
#
#    unitCost  itemAmount    label   branchName
# 0      4.90       -9.80  Damaged  Mayur Vihar
# 1     19.35      -19.35  Damaged  Mayur Vihar

# %%
df
# Out:
#   branchCode   branchName shrinkageNumber              shrinkageDate  \
# 0        MVD  Mayur Vihar            9287  2021-11-11T02:43:15+05:30
#
#   shrinkageBusinessDay  totalAmount status  \
# 0           2021-11-10       -29.15  Final
#
#                                                items
# 0  [{'measuringUnit': 'Piece', 'skuCode': '290', ...

# %%
Final_DF = pd.merge(df,  df_,  on ='branchName',  how ='inner')
name_column = Final_DF.pop('branchName')
Final_DF.insert(1, 'branchName', name_column)
Final_DF.drop('items',axis='columns', inplace=True)
Final_DF
# Out:
#   branchCode   branchName shrinkageNumber              shrinkageDate  \
# 0        MVD  Mayur Vihar            9287  2021-11-11T02:43:15+05:30
# 1        MVD  Mayur Vihar            9287  2021-11-11T02:43:15+05:30
#
#   shrinkageBusinessDay  totalAmount status measuringUnit skuCode  \
# 0           2021-11-10       -29.15  Final         Piece     290
# 1           2021-11-10       -29.15  Final         Piece     298
#
#                              itemName  quantity  unitCost  itemAmount    label
# 0                               Bun 4        -2      4.90       -9.80  Damaged
# 1  Cheese N Veg Delight Patty - Small        -1     19.35      -19.35  Damaged
