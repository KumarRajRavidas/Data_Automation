# %%
import requests
import pandas as pd
import json
import io

# %%
# urlData = requests.get(API).content
# rawData = pd.read_csv(io.StringIO(urlData.decode('utf-8')))

# %% [raw]
# FOR SINGLE OUTLET CHECK

# %%
# from time import gmtime, strftime
# from datetime import datetime
# import datetime
# import requests
# import pandas as pd
# import json
# import jwt
# import time
# import ssl

# from datetime import datetime
# from pytz import timezone
# # format = "%Y-%m-%d %H:%M:%S %Z%z"
# format = "%Y-%m-%d"
# # Current time in UTC
# now_utc = datetime.now(timezone('UTC'))
# # print(now_utc.strftime(format))
# # Convert to Asia/Kolkata time zone
# now_asia = now_utc.astimezone(timezone('Asia/Kolkata'))
# Today = str(now_asia.strftime(format))

# # now = datetime.now()
# # Time = now.strftime("%a %b %d %Y %I:%M GMT(%Z)\n")
# # Time = strftime("%a %b %d %Y %I:%M:%S GMT(%Z)\n")
# # tokenCreationTime = str(datetime.now().time())
# # import time
# print("****************************************************************")
# print("WELCOME RAJ DAS,  HAVE A NICE DAY!! today's date is :",Today)
# print("****************************************************************")
# print('')
# print('Plase wait....')
# # URL = "https://api.ristaapps.com/v1/inventory/item/activity"
# # URL = "https://api.ristaapps.com/v1/items/soldout"
# # URL = "https://api.ristaapps.com/v1/sales/page"
# # URL = "https://api.ristaapps.com/v1"

# URL = "https://api.ristaapps.com/v1/sales/summary"

# # URL = "https://api.ristaapps.com/v1/inventory/item/activity"


# apiKey = 'e1b9bba5-206f-47a7-9904-633b3d95a8c7'
# secretKey = 'mdgGj4sOp5Ly4ed-s2lYFuDrON8nic56L9lJ81nEMmY'

# tokenCreationTime = int(round(time.time()))
# # print(tokenCreationTime)

# payload = {"iss": apiKey, "iat": tokenCreationTime}

# token =   jwt.encode(payload, secretKey) 
# #*************************************************************************************
# # BRANCH_URL = "https://api.ristaapps.com/v1/branch/list"
# # head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
# # response=requests.get(BRANCH_URL,headers=head).json()
# # df = pd.json_normalize(response)
# # Branch_Code=[]
# # for i in df['branchCode']:
# #     Branch_Code.append(str(i))
# #*************************************************************************************    

# # appended_data.append(data)# loop
# # appended_data = pd.concat(appended_data)
# appended_data = []

# #         print("Working Branch :",BC)
# #run your code
# paras = {"branch": 'MNJP', "day":'2021-11-19'}
# head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
# response = requests.get(URL, params=paras, headers=head).json()
# file = response['data']
# print(file)
# df = pd.json_normalize(file)
# appended_data.append(df)# loop


# # requests.get(URL, params=paras, headers=head).json()
# # print(response.text)

# # response = requests.get(URL, headers={'x-api-key': apiKey ,'x-api-token': jwt.encode({ "iss": apiKey, "iat": int(round(time.time())) }, secretKey, algorithm="HS256")}, data={ "iss": apiKey, "iat": int(round(time.time()))})
# # print(response.json())
# # (response).json()
# # print(response.text)
# # print(response)
# appended_data = pd.concat(appended_data)
# print('************************* COMPLETE *****************************')
#     # print(response)
# Out:
# ****************************************************************
# WELCOME RAJ DAS,  HAVE A NICE DAY!! today's date is : 2021-11-20
# ****************************************************************
#
# Plase wait....
# [{'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2386', 'invoiceDate': '2021-11-19T12:31:01+05:30', 'invoiceType': 'Sale', 'chargeAmount': 21.9, 'grossAmount': 284, 'discountAmount': -80, 'taxAmount': 10.2, 'netAmount': 204, 'roundOffAmount': -0.1, 'tipAmount': 0, 'totalAmount': 236, 'channel': 'Burger Singh Swiggy', 'label': '6942', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2387', 'invoiceDate': '2021-11-19T12:31:14+05:30', 'invoiceType': 'Sale', 'chargeAmount': 15.9, 'grossAmount': 159, 'discountAmount': -63.6, 'taxAmount': 4.78, 'netAmount': 95.4, 'roundOffAmount': 0.32, 'tipAmount': 0, 'totalAmount': 116.4, 'channel': 'Burger Singh Swiggy', 'label': '6263', 'status': 'Voided', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2388', 'invoiceDate': '2021-11-19T12:46:31+05:30', 'invoiceType': 'Sale', 'chargeAmount': 7.45, 'grossAmount': 149, 'discountAmount': -74.5, 'taxAmount': 4.1, 'netAmount': 74.5, 'roundOffAmount': 0, 'tipAmount': 0, 'totalAmount': 86.05, 'channel': 'Burger Singh Zomato', 'label': '5228', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2389', 'invoiceDate': '2021-11-19T13:00:46+05:30', 'invoiceType': 'Sale', 'chargeAmount': 7.95, 'grossAmount': 159, 'discountAmount': -79.5, 'taxAmount': 4.38, 'netAmount': 79.5, 'roundOffAmount': 0, 'tipAmount': 0, 'totalAmount': 91.83, 'channel': 'Burger Singh Zomato', 'label': '1142', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2390', 'invoiceDate': '2021-11-19T13:30:48+05:30', 'invoiceType': 'Sale', 'chargeAmount': 22.8, 'grossAmount': 228, 'discountAmount': -92.65, 'taxAmount': 6.76, 'netAmount': 135.35, 'roundOffAmount': 0.44, 'tipAmount': 0, 'totalAmount': 165.35, 'channel': 'Burger Singh Swiggy', 'label': '6762', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2391', 'invoiceDate': '2021-11-19T16:54:41+05:30', 'invoiceType': 'Sale', 'chargeAmount': 11.9, 'grossAmount': 219, 'discountAmount': -100, 'taxAmount': 6.54, 'netAmount': 119, 'roundOffAmount': 0.01, 'tipAmount': 0, 'totalAmount': 137.45, 'channel': 'Burger Singh Zomato', 'label': '9226', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2392', 'invoiceDate': '2021-11-19T16:55:24+05:30', 'invoiceType': 'Sale', 'chargeAmount': 41.7, 'grossAmount': 439, 'discountAmount': -126.65, 'taxAmount': 15.62, 'netAmount': 312.35, 'roundOffAmount': -0.32, 'tipAmount': 0, 'totalAmount': 369.35, 'channel': 'Burger Singh Swiggy', 'label': '0307', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2393', 'invoiceDate': '2021-11-19T18:15:03+05:30', 'invoiceType': 'Sale', 'chargeAmount': 25.4, 'grossAmount': 254, 'discountAmount': -80, 'taxAmount': 8.7, 'netAmount': 174, 'roundOffAmount': -0.1, 'tipAmount': 0, 'totalAmount': 208, 'channel': 'Burger Singh Swiggy', 'label': '1170', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2394', 'invoiceDate': '2021-11-19T18:49:36+05:30', 'invoiceType': 'Sale', 'chargeAmount': 14.8, 'grossAmount': 148, 'discountAmount': -59.2, 'taxAmount': 4.44, 'netAmount': 88.8, 'roundOffAmount': -0.24, 'tipAmount': 0, 'totalAmount': 107.8, 'channel': 'Burger Singh Swiggy', 'label': '5443', 'status': 'Closed', 'saleBy': 'SYSTEM'}, {'branchName': 'Malviya Nagar JP', 'branchCode': 'MNJP', 'invoiceNumber': 'HFFMJ2122-2395', 'invoiceDate': '2021-11-19T18:53:43+05:30', 'invoiceType': 'Sale', 'chargeAmount': 21.9, 'grossAmount': 284, 'discountAmount': -80, 'taxAmount': 10.2, ' ...
# ************************* COMPLETE *****************************

# %%
response
# Out:
# {'data': [{'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2386',
#    'invoiceDate': '2021-11-19T12:31:01+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 21.9,
#    'grossAmount': 284,
#    'discountAmount': -80,
#    'taxAmount': 10.2,
#    'netAmount': 204,
#    'roundOffAmount': -0.1,
#    'tipAmount': 0,
#    'totalAmount': 236,
#    'channel': 'Burger Singh Swiggy',
#    'label': '6942',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2387',
#    'invoiceDate': '2021-11-19T12:31:14+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 15.9,
#    'grossAmount': 159,
#    'discountAmount': -63.6,
#    'taxAmount': 4.78,
#    'netAmount': 95.4,
#    'roundOffAmount': 0.32,
#    'tipAmount': 0,
#    'totalAmount': 116.4,
#    'channel': 'Burger Singh Swiggy',
#    'label': '6263',
#    'status': 'Voided',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2388',
#    'invoiceDate': '2021-11-19T12:46:31+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 7.45,
#    'grossAmount': 149,
#    'discountAmount': -74.5,
#    'taxAmount': 4.1,
#    'netAmount': 74.5,
#    'roundOffAmount': 0,
#    'tipAmount': 0,
#    'totalAmount': 86.05,
#    'channel': 'Burger Singh Zomato',
#    'label': '5228',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2389',
#    'invoiceDate': '2021-11-19T13:00:46+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 7.95,
#    'grossAmount': 159,
#    'discountAmount': -79.5,
#    'taxAmount': 4.38,
#    'netAmount': 79.5,
#    'roundOffAmount': 0,
#    'tipAmount': 0,
#    'totalAmount': 91.83,
#    'channel': 'Burger Singh Zomato',
#    'label': '1142',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2390',
#    'invoiceDate': '2021-11-19T13:30:48+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 22.8,
#    'grossAmount': 228,
#    'discountAmount': -92.65,
#    'taxAmount': 6.76,
#    'netAmount': 135.35,
#    'roundOffAmount': 0.44,
#    'tipAmount': 0,
#    'totalAmount': 165.35,
#    'channel': 'Burger Singh Swiggy',
#    'label': '6762',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2391',
#    'invoiceDate': '2021-11-19T16:54:41+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 11.9,
#    'grossAmount': 219,
#    'discountAmount': -100,
#    'taxAmount': 6.54,
#    'netAmount': 119,
#    'roundOffAmount': 0.01,
#    'tipAmount': 0,
#    'totalAmount': 137.45,
#    'channel': 'Burger Singh Zomato',
#    'label': '9226',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2392',
#    'invoiceDate': '2021-11-19T16:55:24+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 41.7,
#    'grossAmount': 439,
#    'discountAmount': -126.65,
#    'taxAmount': 15.62,
#    'netAmount': 312.35,
#    'roundOffAmount': -0.32,
#    'tipAmount': 0,
#    'totalAmount': 369.35,
#    'channel': 'Burger Singh Swiggy',
#    'label': '0307',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2393',
#    'invoiceDate': '2021-11-19T18:15:03+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 25.4,
#    'grossAmount': 254,
#    'discountAmount': -80,
#    'taxAmount': 8.7,
#    'netAmount': 174,
#    'roundOffAmount': -0.1,
#    'tipAmount': 0,
#    'totalAmount': 208,
#    'channel': 'Burger Singh Swiggy',
#    'label': '1170',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2394',
#    'invoiceDate': '2021-11-19T18:49:36+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 14.8,
#    'grossAmount': 148,
#    'discountAmount': -59.2,
#    'taxAmount': 4.44,
#    'netAmount': 88.8,
#    'roundOffAmount': -0.24,
#    'tipAmount': 0,
#    'totalAmount': 107.8,
#    'channel': 'Burger Singh Swiggy',
#    'label': '5443',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2395',
#    'invoiceDate': '2021-11-19T18:53:43+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 21.9,
#    'grossAmount': 284,
#    'discountAmount': -80,
#    'taxAmount': 10.2,
#    'netAmount': 204,
#    'roundOffAmount': -0.1,
#    'tipAmount': 0,
#    'totalAmount': 236,
#    'channel': 'Burger Singh Swiggy',
#    'label': '0004',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2396',
#    'invoiceDate': '2021-11-19T19:53:03+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 0,
#    'grossAmount': 198,
#    'discountAmount': 0,
#    'taxAmount': 9.9,
#    'netAmount': 198,
#    'roundOffAmount': 0.1,
#    'tipAmount': 0,
#    'totalAmount': 208,
#    'customerId': '48XLLPLL',
#    'customerName': 'Guest',
#    'channel': 'Burger Singh Dine In',
#    'status': 'Closed',
#    'saleBy': 'Malviya Jaipur Outlet'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2397',
#    'invoiceDate': '2021-11-19T20:28:03+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 17.8,
#    'grossAmount': 178,
#    'discountAmount': -75.65,
#    'taxAmount': 5.12,
#    'netAmount': 102.35,
#    'roundOffAmount': 0.08,
#    'tipAmount': 0,
#    'totalAmount': 125.35,
#    'channel': 'Burger Singh Swiggy',
#    'label': '6612',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2398',
#    'invoiceDate': '2021-11-19T20:40:46+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 23.8,
#    'grossAmount': 238,
#    'discountAmount': -101.15,
#    'taxAmount': 6.84,
#    'netAmount': 136.85,
#    'roundOffAmount': 0.36,
#    'tipAmount': 0,
#    'totalAmount': 167.85,
#    'channel': 'Burger Singh Swiggy',
#    'label': '8542',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2399',
#    'invoiceDate': '2021-11-19T21:06:36+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 19.8,
#    'grossAmount': 298,
#    'discountAmount': -100,
#    'taxAmount': 10.88,
#    'netAmount': 198,
#    'roundOffAmount': 0.01,
#    'tipAmount': 0,
#    'totalAmount': 228.69,
#    'channel': 'Burger Singh Zomato',
#    'label': '3986',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2400',
#    'invoiceDate': '2021-11-19T21:12:19+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 8.05,
#    'grossAmount': 161,
#    'discountAmount': -80.5,
#    'taxAmount': 4.42,
#    'netAmount': 80.5,
#    'roundOffAmount': 0.01,
#    'tipAmount': 0,
#    'totalAmount': 92.98,
#    'channel': 'Burger Singh Zomato',
#    'label': '6351',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2401',
#    'invoiceDate': '2021-11-19T22:53:28+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 43.92,
#    'grossAmount': 539.14,
#    'discountAmount': -100,
#    'taxAmount': 24.12,
#    'netAmount': 439.14,
#    'roundOffAmount': 0.03,
#    'tipAmount': 0,
#    'totalAmount': 507.21,
#    'channel': 'Burger Singh Zomato',
#    'label': '0748',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2402',
#    'invoiceDate': '2021-11-19T22:57:13+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 10.18,
#    'grossAmount': 159,
#    'discountAmount': -57.24,
#    'taxAmount': 5.58,
#    'netAmount': 101.76,
#    'roundOffAmount': 0.02,
#    'tipAmount': 0,
#    'totalAmount': 117.54,
#    'channel': 'Burger Singh Zomato',
#    'label': '9991',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'},
#   {'branchName': 'Malviya Nagar JP',
#    'branchCode': 'MNJP',
#    'invoiceNumber': 'HFFMJ2122-2403',
#    'invoiceDate': '2021-11-19T23:07:42+05:30',
#    'invoiceType': 'Sale',
#    'chargeAmount': 9.45,
#    'grossAmount': 189,
#    'discountAmount': -94.5,
#    'taxAmount': 5.2,
#    'netAmount': 94.5,
#    'roundOffAmount': 0,
#    'tipAmount': 0,
#    'totalAmount': 109.15,
#    'channel': 'Burger Singh Zomato',
#    'label': '1117',
#    'status': 'Closed',
#    'saleBy': 'SYSTEM'}]}

# %%
# corona_bra = pd.read_csv(API)
# print(corona_bra.head())

# %%
# file=requests.get(API).json()

# %%
# API Key: e1b9bba5-206f-47a7-9904-633b3d95a8c7
# Secret Key: mdgGj4sOp5Ly4ed-s2lYFuDrON8nic56L9lJ81nEMmY

# %%
# print(file)

# %%
# print(file['data'])

# %%
# Branch_Code= ['AL1','ASH','CHN','CLJ','CP','CSP','DDT','DK','GC1','GDK','GFP','GN','GTB','HO','IN','IP','JAK','JNK','KK','KN','LN','MJ','MN','MVD','N137','N18','N50','NCR' 'WH','NFC','NIT','PV','RA','RDS','RG','RJN','ROH','RP','S122','S49','S7GGN','S81','S83','S9CHD','SC','SCC','SDR','Sec31FBD','SLK','SP','VK']
# for lis in Branch_Code:
#     print(type(lis))

# %%
# from time import gmtime, strftime
# from datetime import datetime
# import datetime
# import requests
# import pandas as pd
# import json
# import jwt
# import time
# import ssl

# # from datetime import datetime
# # from pytz import timezone
# # format = "%Y-%m-%d"
# # now_utc = datetime.now(timezone('UTC'))
# # now_asia = now_utc.astimezone(timezone('Asia/Kolkata'))
# Today = str(now_asia.strftime(format))

# BRANCH_URL = "https://api.ristaapps.com/v1/branch/list"
# apiKey = 'e1b9bba5-206f-47a7-9904-633b3d95a8c7'
# secretKey = 'mdgGj4sOp5Ly4ed-s2lYFuDrON8nic56L9lJ81nEMmY'

# tokenCreationTime = int(round(time.time()))
# payload = {"iss": apiKey, "iat": tokenCreationTime}
# token =   jwt.encode(payload, secretKey) 

# head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
# response=requests.get(BRANCH_URL,headers=head).json()
# df = pd.json_normalize(response)

# Branch_Code=[]
# Branch_Name=[]
# for i in df['branchCode']:
#     Branch_Code.append(str(i))
# Branch_Code
# for j in df['branchName']:
#     Branch_Name.append(str(i))

# %%
# df.drop(columns=['channels'],inplace=True)

# %%
# df

# %%
# from time import gmtime, strftime
# from datetime import datetime
# import datetime
# import requests
# import pandas as pd
# import json
# import jwt
# import time
# import ssl

# from datetime import datetime
# from pytz import timezone
# # format = "%Y-%m-%d %H:%M:%S %Z%z"
# format = "%Y-%m-%dT%H:%M:%S"

# # format = "%Y-%m-%d"
# # Current time in UTC
# now_utc = datetime.now(timezone('UTC'))
# # print(now_utc.strftime(format))
# # Convert to Asia/Kolkata time zone
# now_asia = now_utc.astimezone(timezone('Asia/Kolkata'))
# print(str(now_asia.strftime(format)))
# Out:
# 2021-11-22T13:14:22

# %%
from time import gmtime, strftime
from datetime import datetime
import datetime
import requests
import pandas as pd
import json
import jwt
import time
import ssl

from datetime import datetime
from pytz import timezone
# format = "%Y-%m-%d %H:%M:%S %Z%z"
format = "%Y-%m-%d"
# Current time in UTC
now_utc = datetime.now(timezone('UTC'))
# print(now_utc.strftime(format))
# Convert to Asia/Kolkata time zone
now_asia = now_utc.astimezone(timezone('Asia/Kolkata'))
Today = str(now_asia.strftime(format))

# now = datetime.now()
# Time = now.strftime("%a %b %d %Y %I:%M GMT(%Z)\n")
# Time = strftime("%a %b %d %Y %I:%M:%S GMT(%Z)\n")
# tokenCreationTime = str(datetime.now().time())
# import time
# print("****************************************************************")
# print("WELCOME RAJ DAS,  HAVE A NICE DAY!! today's date is :",Today)
# print("****************************************************************")
print('')
print('Plase wait....')
# URL = "https://api.ristaapps.com/v1/inventory/item/activity"
# URL = "https://api.ristaapps.com/v1/items/soldout"
# URL = "https://api.ristaapps.com/v1/sales/page"
# URL = "https://api.ristaapps.com/v1"

URL = "https://api.ristaapps.com/v1/sales/page"

# URL = "https://api.ristaapps.com/v1/inventory/item/activity"


apiKey = 'e1b9bba5-206f-47a7-9904-633b3d95a8c7'
secretKey = 'mdgGj4sOp5Ly4ed-s2lYFuDrON8nic56L9lJ81nEMmY'

# print(tokenCreationTime)

#*************************************************************************************
BRANCH_URL = "https://api.ristaapps.com/v1/branch/list"
tokenCreationTime = int(round(time.time()))
payload = {"iss": apiKey, "iat": tokenCreationTime}
token =   jwt.encode(payload, secretKey) 
head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
response=requests.get(BRANCH_URL,headers=head).json()
df = pd.json_normalize(response)
Branch_Code=[]
for i in df['branchCode']:
    Branch_Code.append(str(i))
#*************************************************************************************    

# appended_data.append(data)# loop
# appended_data = pd.concat(appended_data)
appended_data = []
DATE='2021-11-22'
for BC in Branch_Code:
    print('************',BC,'************')
    Key=''
    tokenCreationTime = int(round(time.time()))
#     print(tokenCreationTime)
    payload = {"iss": apiKey, "iat": tokenCreationTime}
    token =   jwt.encode(payload, secretKey) 
    paras = {"branch": BC, "day": DATE}
    head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
    response = requests.get(URL, params=paras, headers=head).json()
    file = response['data']
    df = pd.json_normalize(file)
    appended_data.append(df)
    try:
        Key = response['lastKey']
    except:
        pass
    print('First Key',Key )
    try:
        while True:
            tokenCreationTime = int(round(time.time()))
            payload = {"iss": apiKey, "iat": tokenCreationTime}
            token =   jwt.encode(payload, secretKey) 
#             Key = response['lastKey']
#             print('Inside While')
            paras = {"branch": BC, "day": DATE, "lastKey" : Key}
            head = {"x-api-token": token, "x-api-key": apiKey,  'content-type': 'application/json'}
            response = requests.get(URL, params=paras, headers=head).json()
#             print('response is:', response )
            file = response['data']
            df = pd.json_normalize(file)
            appended_data.append(df)
            Key = response['lastKey']#nn
            print('Last Key is:',Key)
    except:
        pass

        
#     except:
# #         print('Erro')
# #         print("Not Working Branch :",BC)
#         pass
# requests.get(URL, params=paras, headers=head).json()
# print(response.text)

# response = requests.get(URL, headers={'x-api-key': apiKey ,'x-api-token': jwt.encode({ "iss": apiKey, "iat": int(round(time.time())) }, secretKey, algorithm="HS256")}, data={ "iss": apiKey, "iat": int(round(time.time()))})
# print(response.json())
# (response).json()
# print(response.text)
# print(response)
appended_data = pd.concat(appended_data)         
print('************************* COMPLETE *****************************')
    # print(response)
# Out:
# Plase wait....
# ************ IN ************
# First Key SIN2122-6543
# Last Key is: SIN2122-6563
# Last Key is: SIN2122-6583
# Last Key is: SIN2122-6603
# Last Key is: SIN2122-6623
# ************ CP ************
# First Key TPCP2122-7282
# Last Key is: TPCP2122-7303
# Last Key is: TPCP2122-7323
# Last Key is: TPCP2122-7343
# ************ N50 ************
# First Key BBN502122-6787
# Last Key is: BBN502122-6807
# Last Key is: BBN502122-6827
# Last Key is: BBN502122-6847
# Last Key is: BBN502122-6867
# Last Key is: BBN502122-6887
# ************ HO ************
# First Key
# ************ WH ************
# First Key
# ************ SLK ************
# First Key TPSL2122-9755
# Last Key is: TPSL2122-9775
# Last Key is: TPSL2122-9795
# Last Key is: TPSL2122-9815
# Last Key is: TPSL2122-9835
# Last Key is: TPSL2122-9855
# Last Key is: TPSL2122-9875
# ************ KN ************
# First Key TMPPLKN-14957
# Last Key is: TMPPLKN-14977
# Last Key is: TMPPLKN-14997
# Last Key is: TMPPLKN-15017
# Last Key is: TMPPLKN-15037
# Last Key is: TMPPLKN-15057
# Last Key is: TMPPLKN-15077
# ************ JNK ************
# First Key TPJNK2122-8967
# Last Key is: TPJNK2122-8987
# Last Key is: TPJNK2122-9007
# Last Key is: TPJNK2122-9027
# Last Key is: TPJNK2122-9047
# Last Key is: TPJNK2122-9067
# Last Key is: TPJNK2122-9087
# ************ PV ************
# First Key TPPV2122-6639
# Last Key is: TPPV2122-6659
# Last Key is: TPPV2122-6679
# Last Key is: TPPV2122-6699
# ************ SP ************
# First Key MKSP2122-5165
# Last Key is: MKSP2122-5185
# Last Key is: MKSP2122-5205
# ************ GTB ************
# First Key TPGTB2122-6889
# Last Key is: TPGTB2122-6909
# Last Key is: TPGTB2122-6929
# Last Key is: TPGTB2122-6949
# ************ SC ************
# First Key TPSC2122-7869
# Last Key is: TPSC2122-7889
# Last Key is: TPSC2122-7909
# Last Key is: TPSC2122-7929
# Last Key is: TPSC2122-7949
# ************ KKJ ************
# First Key TPKKJ2122-6494
# Last Key is: TPKKJ2122-6514
# Last Key is: TPKKJ2122-6534
# ************ VK ************
# First Key TMPVK2122-7885
# Last Key is: TMPVK2122-7905
# Last Key is: TMPVK2122-7925
# Last Key is: TMPVK2122-7945
# Last Key is: TMPVK2122-7965
# ************ N137 ************
# First Key BBN13721226550
# Last Key is: BBN13721226570
# Last Key is: BBN13721226590
# Last Key is: BBN13721226610
# Last Key is: BBN13721226630
# Last Key is: BBN13721226650
# ************ ROH ************
# First Key TPROH2122-10322
# Last Key is: TPROH2122-10342
# Last Key is: TPROH2122-10362
# Last Key is: TPROH2122-10382
# Last Key is: TPROH2122-10402
# Last Key is: TPROH2122-10422
# ************ RP ************
# First Key TPRP2122-5009
# Last Key is: TPRP2122-5029
# Last Key is: TPRP2122-5049
# ************ NITFBD ************
# First Key CFNIT2122-6484
# Last Key is: CFNIT2122-6504
# Last Key is: CFNIT2122-6524
# Last Key is: CFNIT2122-6544
# ************ SD ************
# First Key MKSDR2122-2527
# Last Key is: MKSDR2122-2547
# ************ MN ************
# First Key TPMLV2122-9728
# Last Key is: TPMLV2122-9748
# Last Key is: TPMLV2122-9768
# Last Key is: TPMLV2122-9788
# Last Key is: TPMLV2122-9808
# Last Key is: TPMLV2122-9828
# Last Key is: TPMLV2122-9848
# ************ RN ************
# First Key FWRJN2122-5829
# Last Key is: FWRJN2122-5849
# Last Key is: FWRJN2122-5869
# Last Key is: FWRJN2122-5889
# Last Key is: FWRJN2122-5909
# Last Key is: FWRJN2122-5929
# Last Key is: FWRJN2122-5949
# ************ RAA ************
# First Key TBRA2122-7047
# Last Key is: TBRA2122-7067
# Last Key is: TBRA2122-7087
# Last Key is: TBRA2122-7107
# Last Key is: TBRA2122-7127
# Last Key is: TBRA2122-7147
# ************ RS ************
# First Key
# ************ SCPX ************
# First Key
# ************ LN ************
# First Key RALN2122-4388
# Last Key is: RALN2122-4408
# Last Key is: RALN2122-4428
# ************ SEC81 ************
# First Key CFS812122-5801
# Last Key is: CFS812122-5821
# Last Key is: CFS812122-5841
# ************ N18 ************
# First Key ASN182122-4326
# Last Key is: ASN182122-4346
# Last Key is: ASN182122-4366
# Last Key is: ASN182122-4386
# Last Key is: ASN182122-4406
# ************ IP ************
# First Key GRIP2122-6887
# Last Key is: GRIP2122-6907
# Last Key is: GRIP2122-6927
# Last Key is: GRIP2122-6947
# Last Key is: GRIP2122-6967
# Last Key is: GRIP2122-6987
# ************ PN ************
# First Key
# ************ RG ************
# First Key MPRG2122-7849
# Last Key is: MPRG2122-7869
# Last Key is: MPRG2122-7889
# Last Key is: MPRG2122-7909
# Last Key is: MPRG2122-7929
# Last Key is: MPRG2122-7949
# ************ SEC83 ************
# First Key NES832122-5160
# Last Key is: NES832122-5180
# Last Key is: NES832122-5200
# ************ NFC ************
# First Key NCNFC2122-3084
# ************ MT ************
# First Key
# ************ SEC7 ************
# First Key HSS72122-4151
# Last Key is: HSS72122-4171
# Last Key is: HSS72122-4191
# Last Key is: HSS72122-4211
# ************ GFP ************
# First Key SCGFP2122-2380
# ************ SEC31 ************
# First Key FIS312122-5582
# Last Key is: FIS312122-5602
# Last Key is: FIS312122-5622
# Last Key is: FIS312122-5642
# ************ A1 ************
# First Key IFAL12122-5737
# Last Key is: IFAL12122-5757
# Last Key is: IFAL12122-5777
# Last Key is: IFAL12122-5797
# Last Key is: IFAL12122-5817
# ************ GN ************
# First Key BCGN2122-8390
# Last Key is: BCGN2122-8410
# Last Key is: BCGN2122-8430
# Last Key is: BCGN2122-8450
# Last Key is: BCGN2122-8470
# Last Key is: BCGN2122-8490
# ************ CL ************
# First Key AECLJ2122-4689
# Last Key is: AECLJ2122-4709
# Last Key is: AECLJ2122-4729
# ************ SEC9 ************
# First Key TUPS92122-10939
# Last Key is: TUPS92122-10959
# Last Key is: TUPS92122-10979
# Last Key is: TUPS92122-10999
# Last Key is: TUPS92122-11019
# Last Key is: TUPS92122-11039
# Last Key is: TUPS92122-11059
# Last Key is: TUPS92122-11079
# Last Key is: TUPS92122-11099
# Last Key is: TUPS92122-11119
# ************ DDT ************
# First Key AEDV21222157
# Last Key is: AEDV21222177
# Last Key is: AEDV21222197
# Last Key is: AEDV21222217
# Last Key is: AEDV21222237
# Last Key is: AEDV21222257
# Last Key is: AEDV21222277
# Last Key is: AEDV21222297
# ************ MNJP ************
# First Key
# ************ SEC122 ************
# First Key IFS12221224377
# Last Key is: IFS12221224397
# Last Key is: IFS12221224417
# ************ SEC49 ************
# First Key SS492122-6287
# Last Key is: SS492122-6307
# Last Key is: SS492122-6327
# Last Key is: SS492122-6347
# Last Key is: SS492122-6367
# ************ AS ************
# First Key AFR2122-5290
# Last Key is: AFR2122-5310
# Last Key is: AFR2122-5330
# Last Key is: AFR2122-5350
# ************ CS ************
# First Key
# ************ DWK ************
# First Key TPDW2122-10992
# Last Key is: TPDW2122-11012
# Last Key is: TPDW2122-11032
# Last Key is: TPDW2122-11052
# Last Key is: TPDW2122-11072
# Last Key is: TPDW2122-11092
# ************ TDI ************
# First Key
# ************ JAK ************
# First Key DJAK2122-1343
# Last Key is: DJAK2122-1363
# Last Key is: DJAK2122-1383
# Last Key is: DJAK2122-1403
# ************ PPL ************
# First Key
# ************ CHN ************
# First Key NDCHN2122-3268
# Last Key is: NDCHN2122-3288
# Last Key is: NDCHN2122-3308
# Last Key is: NDCHN2122-3328
# ************ GC1 ************
# First Key ABGC2122-5741
# Last Key is: ABGC2122-5761
# Last Key is: ABGC2122-5781
# Last Key is: ABGC2122-5801
# Last Key is: ABGC2122-5821
# ************ GDK ************
# First Key KFGDK21229621
# Last Key is: KFGDK21229641
# Last Key is: KFGDK21229661
# Last Key is: KFGDK21229681
# Last Key is: KFGDK21229701
# Last Key is: KFGDK21229721
# Last Key is: KFGDK21229741
# Last Key is: KFGDK21229761
# Last Key is: KFGDK21229781
# Last Key is: KFGDK21229801
# Last Key is: KFGDK21229821
# ************ SNM ************
# First Key
# ************ MVD ************
# First Key KZMVD2122-2224
# Last Key is: KZMVD2122-2244
# ************ RWH ************
# First Key
# ************************* COMPLETE *****************************

# %%
appended_data
# Out:
#            branchName branchCode     brandName   invoiceNumber  \
# 0    Indira Nagar DDN         IN  Burger Singh    SIN2122-6013
# 1    Indira Nagar DDN         IN  Burger Singh    SIN2122-6014
# 2    Indira Nagar DDN         IN  Burger Singh    SIN2122-6015
# 3    Indira Nagar DDN         IN  Burger Singh    SIN2122-6016
# 4    Indira Nagar DDN         IN  Burger Singh    SIN2122-6017
# ..                ...        ...           ...             ...
# 19  Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1989
# 0   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1990
# 1   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1991
# 2   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1992
# 3   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1993
#
#                   invoiceDate                createdDate  \
# 0   2021-11-18T12:05:47+05:30  2021-11-18T12:05:47+05:30
# 1   2021-11-18T12:08:09+05:30  2021-11-18T12:08:09+05:30
# 2   2021-11-18T12:19:56+05:30  2021-11-18T12:19:56+05:30
# 3   2021-11-18T12:20:53+05:30  2021-11-18T12:20:53+05:30
# 4   2021-11-18T12:24:45+05:30  2021-11-18T12:24:45+05:30
# ..                        ...                        ...
# 19  2021-11-19T00:40:43+05:30  2021-11-19T00:40:43+05:30
# 0   2021-11-19T00:50:48+05:30  2021-11-19T00:50:48+05:30
# 1   2021-11-19T01:21:21+05:30  2021-11-19T01:21:21+05:30
# 2   2021-11-19T01:49:10+05:30  2021-11-19T01:49:10+05:30
# 3   2021-11-19T02:56:04+05:30  2021-11-19T02:56:04+05:30
#
#                  modifiedDate invoiceType  \
# 0   2021-11-18T12:27:44+05:30        Sale
# 1   2021-11-18T12:46:19+05:30        Sale
# 2   2021-11-18T12:48:17+05:30        Sale
# 3   2021-11-18T12:55:00+05:30        Sale
# 4   2021-11-18T13:09:29+05:30        Sale
# ..                        ...         ...
# 19  2021-11-19T00:44:35+05:30        Sale
# 0   2021-11-19T01:26:39+05:30        Sale
# 1   2021-11-19T01:45:37+05:30        Sale
# 2   2021-11-19T02:08:37+05:30        Sale
# 3   2021-11-19T03:16:03+05:30        Sale
#
#                                          note fulfillmentStatus  ...  \
# 0                                                     Delivered  ...
# 1                          Don't send cutlery         Delivered  ...
# 2         Send Cutlery, \nNear ballupur chowk         Delivered  ...
# 3                    Send Cutlery, \nNear pnb         Delivered  ...
# 4   Don't send cutlery, \nNear T.B RANA house         Delivered  ...
# ..                                        ...               ...  ...
# 19                         Don't send cutlery          Accepted  ...
# 0                                                     Delivered  ...
# 1                          Don't send cutlery         Delivered  ...
# 2      Don't send cutlery, \nNear govt school         Delivered  ...
# 3   Don't send cutlery, \nSheetla mata mandir         Delivered  ...
#
#    delivery.address.state delivery.address.country delivery.address.zip  \
# 0                     NaN                      NaN                  NaN
# 1                                            India
# 2                                            India
# 3                                            India
# 4                                            India
# ..                    ...                      ...                  ...
# 19                                           India
# 0                     NaN                      NaN                  NaN
# 1                                            India
# 2                                            India
# 3                                            India
#
#     deviceLabel customer.name  customer.phoneNumber  customer.id  \
# 0           NaN           NaN                   NaN          NaN
# 1           NaN           NaN                   NaN          NaN
# 2           NaN           NaN                   NaN          NaN
# 3           NaN           NaN                   NaN          NaN
# 4           NaN           NaN                   NaN          NaN
# ..          ...           ...                   ...          ...
# 19          NaN           NaN                   NaN          NaN
# 0           NaN           NaN                   NaN          NaN
# 1           NaN           NaN                   NaN          NaN
# 2           NaN           NaN                   NaN          NaN
# 3           NaN           NaN                   NaN          NaN
#
#               statusInfo.reason  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 19  Cancelled by zomato. reject
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
#
#                                    statusInfo.remarks  delivery.email
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# ..                                                ...             ...
# 19  Accepted 4 minutes ago. Cancelled by zomato. r...             NaN
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
#
# [5346 rows x 65 columns]

# %%
# appended_data.columns

# %%
# for i in appended_data.columns:
#     print(i)

# %%
# appended_data

# %%
# F=appended_data['createdDate']
# print(F)
appended_data.drop(columns=['items', 'charges', 'taxes', 'payments','url','eventLog','discounts'],inplace=True)
# appended_data['branchCode']

# %%
# appended_data.to_excel('file_name_21.xlsx', index=False)

# %%
# Date_value = appended_data['createdDate']
# appended_data['createdDate']

# %%
# appended_data
# appended_data.to_excel('file_name_.xlsx', index=False)
appended_data['Hour'] = appended_data['createdDate'].str[11:13]
name_column = appended_data.pop('Hour')
appended_data.insert(8, 'Hour', name_column)
# appended_data['modifiedDate'] = appended_data['modifiedDate'].str[0:10]
appended_data
# Out:
#            branchName branchCode     brandName   invoiceNumber  \
# 0    Indira Nagar DDN         IN  Burger Singh    SIN2122-6013
# 1    Indira Nagar DDN         IN  Burger Singh    SIN2122-6014
# 2    Indira Nagar DDN         IN  Burger Singh    SIN2122-6015
# 3    Indira Nagar DDN         IN  Burger Singh    SIN2122-6016
# 4    Indira Nagar DDN         IN  Burger Singh    SIN2122-6017
# ..                ...        ...           ...             ...
# 19  Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1989
# 0   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1990
# 1   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1991
# 2   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1992
# 3   Mayur Vihar Delhi        MVD  Burger Singh  KZMVD2122-1993
#
#                   invoiceDate                createdDate  \
# 0   2021-11-18T12:05:47+05:30  2021-11-18T12:05:47+05:30
# 1   2021-11-18T12:08:09+05:30  2021-11-18T12:08:09+05:30
# 2   2021-11-18T12:19:56+05:30  2021-11-18T12:19:56+05:30
# 3   2021-11-18T12:20:53+05:30  2021-11-18T12:20:53+05:30
# 4   2021-11-18T12:24:45+05:30  2021-11-18T12:24:45+05:30
# ..                        ...                        ...
# 19  2021-11-19T00:40:43+05:30  2021-11-19T00:40:43+05:30
# 0   2021-11-19T00:50:48+05:30  2021-11-19T00:50:48+05:30
# 1   2021-11-19T01:21:21+05:30  2021-11-19T01:21:21+05:30
# 2   2021-11-19T01:49:10+05:30  2021-11-19T01:49:10+05:30
# 3   2021-11-19T02:56:04+05:30  2021-11-19T02:56:04+05:30
#
#                  modifiedDate invoiceType Hour  \
# 0   2021-11-18T12:27:44+05:30        Sale   12
# 1   2021-11-18T12:46:19+05:30        Sale   12
# 2   2021-11-18T12:48:17+05:30        Sale   12
# 3   2021-11-18T12:55:00+05:30        Sale   12
# 4   2021-11-18T13:09:29+05:30        Sale   12
# ..                        ...         ...  ...
# 19  2021-11-19T00:44:35+05:30        Sale   00
# 0   2021-11-19T01:26:39+05:30        Sale   00
# 1   2021-11-19T01:45:37+05:30        Sale   01
# 2   2021-11-19T02:08:37+05:30        Sale   01
# 3   2021-11-19T03:16:03+05:30        Sale   02
#
#                                          note  ... delivery.address.state  \
# 0                                              ...                    NaN
# 1                          Don't send cutlery  ...
# 2         Send Cutlery, \nNear ballupur chowk  ...
# 3                    Send Cutlery, \nNear pnb  ...
# 4   Don't send cutlery, \nNear T.B RANA house  ...
# ..                                        ...  ...                    ...
# 19                         Don't send cutlery  ...
# 0                                              ...                    NaN
# 1                          Don't send cutlery  ...
# 2      Don't send cutlery, \nNear govt school  ...
# 3   Don't send cutlery, \nSheetla mata mandir  ...
#
#    delivery.address.country delivery.address.zip deviceLabel  customer.name  \
# 0                       NaN                  NaN         NaN            NaN
# 1                     India                              NaN            NaN
# 2                     India                              NaN            NaN
# 3                     India                              NaN            NaN
# 4                     India                              NaN            NaN
# ..                      ...                  ...         ...            ...
# 19                    India                              NaN            NaN
# 0                       NaN                  NaN         NaN            NaN
# 1                     India                              NaN            NaN
# 2                     India                              NaN            NaN
# 3                     India                              NaN            NaN
#
#     customer.phoneNumber  customer.id            statusInfo.reason  \
# 0                    NaN          NaN                          NaN
# 1                    NaN          NaN                          NaN
# 2                    NaN          NaN                          NaN
# 3                    NaN          NaN                          NaN
# 4                    NaN          NaN                          NaN
# ..                   ...          ...                          ...
# 19                   NaN          NaN  Cancelled by zomato. reject
# 0                    NaN          NaN                          NaN
# 1                    NaN          NaN                          NaN
# 2                    NaN          NaN                          NaN
# 3                    NaN          NaN                          NaN
#
#                                    statusInfo.remarks  delivery.email
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# ..                                                ...             ...
# 19  Accepted 4 minutes ago. Cancelled by zomato. r...             NaN
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
#
# [5346 rows x 59 columns]

# %%
# appended_data.to_excel('file_name_18.xlsx', index=False)

# %%
# for i in appended_data.columns:
#     print(i)
column_= appended_data.columns
# print(parse_column)
# print(column)

# %%
COLUMN_NAMES=[ 'branchCode', 'branchName','brandName', 'Hour', 'invoiceNumber', 'orderNumber','invoiceDate', 'createdDate', 'modifiedDate', 'deviceLabel',
    'invoiceType', 'status', 'fulfillmentStatus', 'label', 'labelGroup','sessionLabel', 'personCount', 'saleBy', 'saleByUserId', 'channel',
   'currency', 'itemCount', 'items', 'itemTotalAmount', 'chargeAmount','discountAmount', 'itemDiscountAmount', 'totalDiscountAmount','taxAmountIncluded', 'taxAmountExcluded', 'taxAmount', 'grossAmount',
   'netDiscountAmount', 'netAmount', 'netChargeAmount', 'billAmount','roundOffAmount', 'billRoundedAmount', 'tipAmount', 'totalAmount','totalCost', 'note', 'charges', 'discounts', 'taxes', 'payments',
   'loyalties', 'url', 'eventLog', 'tags', 'sourceInfo.companyName', 'sourceInfo.invoiceNumber', 'sourceInfo.invoiceDate','sourceInfo.callbackURL', 'sourceInfo.source',
   'sourceInfo.sourceOutletId', 'sourceInfo.outletId', 'sourceInfo.isEditable', 'sourceInfo.verifyCoupons','originalSaleInfo.invoiceNumber', 'delivery.title', 'delivery.name',
   'delivery.email', 'delivery.phoneNumber', 'delivery.mode', 'delivery.address.label', 'delivery.address.addressLine',
   'delivery.address.city', 'delivery.address.state', 'delivery.address.country', 'delivery.address.zip',
   'delivery.address.landmark', 'delivery.address.latitude', 'delivery.address.longitude', 'delivery.deliveryDate',
   'deliveryBy.name', 'deliveryBy.email', 'deliveryBy.phoneNumber', 'customer.id', 'customer.title', 'customer.name', 'customer.email',
   'customer.phoneNumber', 'customer.taxId', 'statusInfo.reason', 'statusInfo.remarks', 'resourceInfo.resourceId',
   'resourceInfo.resourceName', 'resourceInfo.groupSize','resourceInfo.resourceGroupName','delivery.paymentMode']
DF = pd.DataFrame(columns=COLUMN_NAMES)
# DF.columns

# %%
DF
# Out:
# Empty DataFrame
# Columns: [branchCode, branchName, brandName, Hour, invoiceNumber, orderNumber, invoiceDate, createdDate, modifiedDate, deviceLabel, invoiceType, status, fulfillmentStatus, label, labelGroup, sessionLabel, personCount, saleBy, saleByUserId, channel, currency, itemCount, items, itemTotalAmount, chargeAmount, discountAmount, itemDiscountAmount, totalDiscountAmount, taxAmountIncluded, taxAmountExcluded, taxAmount, grossAmount, netDiscountAmount, netAmount, netChargeAmount, billAmount, roundOffAmount, billRoundedAmount, tipAmount, totalAmount, totalCost, note, charges, discounts, taxes, payments, loyalties, url, eventLog, tags, sourceInfo.companyName, sourceInfo.invoiceNumber, sourceInfo.invoiceDate, sourceInfo.callbackURL, sourceInfo.source, sourceInfo.sourceOutletId, sourceInfo.outletId, sourceInfo.isEditable, sourceInfo.verifyCoupons, originalSaleInfo.invoiceNumber, delivery.title, delivery.name, delivery.email, delivery.phoneNumber, delivery.mode, delivery.address.label, delivery.address.addressLine, delivery.address.city, delivery.address.state, delivery.address.country, delivery.address.zip, delivery.address.landmark, delivery.address.latitude, delivery.address.longitude, delivery.deliveryDate, deliveryBy.name, deliveryBy.email, deliveryBy.phoneNumber, customer.id, customer.title, customer.name, customer.email, customer.phoneNumber, customer.taxId, statusInfo.reason, statusInfo.remarks, resourceInfo.resourceId, resourceInfo.resourceName, resourceInfo.groupSize, resourceInfo.resourceGroupName, delivery.paymentMode]
# Index: []
#
# [0 rows x 91 columns]

# %%
for column in COLUMN_NAMES:
    if column  in column_:
        value= appended_data[column]
        #         DF.insert(count,column,value)
        DF[column]=value
#         print('Match')
#         count=1+count
#     else:
#         appended_data[column] =0
#         count1=1+count1
#         value_= 0
#         DF.insert(count,column,value_)
#         print('Not Match')
# print(count)
# print(count1)

# %%
DF
# Out:
#    branchCode         branchName     brandName Hour   invoiceNumber  \
# 0          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6013
# 1          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6014
# 2          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6015
# 3          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6016
# 4          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6017
# ..        ...                ...           ...  ...             ...
# 19        MVD  Mayur Vihar Delhi  Burger Singh   00  KZMVD2122-1989
# 0         MVD  Mayur Vihar Delhi  Burger Singh   00  KZMVD2122-1990
# 1         MVD  Mayur Vihar Delhi  Burger Singh   01  KZMVD2122-1991
# 2         MVD  Mayur Vihar Delhi  Burger Singh   01  KZMVD2122-1992
# 3         MVD  Mayur Vihar Delhi  Burger Singh   02  KZMVD2122-1993
#
#    orderNumber                invoiceDate                createdDate  \
# 0          NaN  2021-11-18T12:05:47+05:30  2021-11-18T12:05:47+05:30
# 1          NaN  2021-11-18T12:08:09+05:30  2021-11-18T12:08:09+05:30
# 2          NaN  2021-11-18T12:19:56+05:30  2021-11-18T12:19:56+05:30
# 3          NaN  2021-11-18T12:20:53+05:30  2021-11-18T12:20:53+05:30
# 4          NaN  2021-11-18T12:24:45+05:30  2021-11-18T12:24:45+05:30
# ..         ...                        ...                        ...
# 19         NaN  2021-11-19T00:40:43+05:30  2021-11-19T00:40:43+05:30
# 0          NaN  2021-11-19T00:50:48+05:30  2021-11-19T00:50:48+05:30
# 1          NaN  2021-11-19T01:21:21+05:30  2021-11-19T01:21:21+05:30
# 2          NaN  2021-11-19T01:49:10+05:30  2021-11-19T01:49:10+05:30
# 3          NaN  2021-11-19T02:56:04+05:30  2021-11-19T02:56:04+05:30
#
#                  modifiedDate deviceLabel  ... customer.email  \
# 0   2021-11-18T12:27:44+05:30         NaN  ...            NaN
# 1   2021-11-18T12:46:19+05:30         NaN  ...            NaN
# 2   2021-11-18T12:48:17+05:30         NaN  ...            NaN
# 3   2021-11-18T12:55:00+05:30         NaN  ...            NaN
# 4   2021-11-18T13:09:29+05:30         NaN  ...            NaN
# ..                        ...         ...  ...            ...
# 19  2021-11-19T00:44:35+05:30         NaN  ...            NaN
# 0   2021-11-19T01:26:39+05:30         NaN  ...            NaN
# 1   2021-11-19T01:45:37+05:30         NaN  ...            NaN
# 2   2021-11-19T02:08:37+05:30         NaN  ...            NaN
# 3   2021-11-19T03:16:03+05:30         NaN  ...            NaN
#
#    customer.phoneNumber customer.taxId            statusInfo.reason  \
# 0                   NaN            NaN                          NaN
# 1                   NaN            NaN                          NaN
# 2                   NaN            NaN                          NaN
# 3                   NaN            NaN                          NaN
# 4                   NaN            NaN                          NaN
# ..                  ...            ...                          ...
# 19                  NaN            NaN  Cancelled by zomato. reject
# 0                   NaN            NaN                          NaN
# 1                   NaN            NaN                          NaN
# 2                   NaN            NaN                          NaN
# 3                   NaN            NaN                          NaN
#
#                                    statusInfo.remarks resourceInfo.resourceId  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# ..                                                ...                     ...
# 19  Accepted 4 minutes ago. Cancelled by zomato. r...                     NaN
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
#
#    resourceInfo.resourceName resourceInfo.groupSize  \
# 0                       5426                    NaN
# 1                       3256                    NaN
# 2                       7833                    NaN
# 3                       9449                    NaN
# 4                       9231                    NaN
# ..                       ...                    ...
# 19                      1673                    NaN
# 0                       2203                    NaN
# 1                       9861                    NaN
# 2                       7146                    NaN
# 3                       7573                    NaN
#
#    resourceInfo.resourceGroupName delivery.paymentMode
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# ..                            ...                  ...
# 19                            NaN                  NaN
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
#
# [5346 rows x 91 columns]

# %%
# DF.columns

# %%
# for i in range(len(DF.columns)):

# %%
# sold_in_bulk = appended_data.dataframe ['branchName']

# %%
# count=0
# for i in df.columns:
#     count=1+count
# #     print(i)
# print(count)
# df

# %%
# columns = ['col1', 'col2', 'col3', 'col4', 'col5']
# dfAll = pd.DataFrame(columns=columns)
# df= pd.read_excel('FilePath', sheetname='data1') # contains 3 columns i.e             col1, col2, col5
# columnsOFdf = df.columns
# for column in columns:
#     if column not in columnsOFdf:
#         df[column] = [""] * df.shape[0]
# dfAll.append(df)

# columns = ['col1', 'col2', 'col3', 'col4', 'col5']
# dfAll = pd.DataFrame(columns=columns)
# df= pd.read_excel('FilePath', sheetname='data1') # contains 3 column appended_data

# appended_data_col = appended_data.columns
# for column in COLUMN_NAMES:
#     if column  in appended_data_col:
#         DF[column] =  appended_data.shape[0]
# N=DF.append(appended_data)

# %%
# DF.to_excel('file_name_new_14.xlsx', index=False)

# %%
# appended_data.dtypes

# %%
# appended_data=appended_data.applymap(str)

# %%
# import pandas as pd
# import gspread
# import gspread_dataframe as gd
# from gspread_dataframe import set_with_dataframe


# gc = gspread.service_account(filename='universalsolder.json')
# # sh = gc.open_by_key('1hwqYXSi7vMHvHHZcJ2ru3T8sxkpiAy1Tlxry_FgGDzk')#sales_summary
# sh = gc.open_by_key('1Zpv-pw0NJrG5POmJcNMPql3FSL6U9FmlZ9Pj8FcvgPg')#sales_page

# worksheet = sh.get_worksheet(0) #-> 0 - first sheet, 1 - second sheet etc. 
# set_with_dataframe(worksheet, DF)

# ws= set_with_dataframe(worksheet, appended_data)


# ws = gc.open("SheetName").worksheet("xyz")
# existing = gd.get_as_dataframe(ws)
# updated = existing.append(your_new_data)
# gd.set_with_dataframe(ws, updated)


# ws = gc.open("Sales_page").worksheet("Sheet1")# Warning
# existing = gd.get_as_dataframe(ws)
# updated = existing.append(appended_data)
# gd.set_with_dataframe(ws, updated)

# %%
# from pandas.io.json import json_normalize
# df = pd.io.json.json_normalize(file)
# df.to_csv('file_name.csv', index=False)

# %%
# import pandas as pd
# from pandas.io import gbq
# # from google.cloud import bigquery
# import os
# df.to_gbq(destination_table='SalePage', project_id='bs-supply-chain:SalesPage',  if_exists='fail')

# %%
# from google.cloud import bigquery
# import os

# %%
# import json

# # Opening JSON file
# f = open('sale.json',)

# # returns JSON object as
# # a dictionary
# data = json.load(f)

# Iterating through the json
# lisbt
# for i in data['emp_details']:
# 	print(i)

# # Closing file
# f.close()

# %%
# file_Json = data['data']
# df = pd.json_normalize(file_Json)

# %%
# li=df.columns
# print(li)

# %%
# rawData = pd.read_csv('Sale Transactions Audit.csv')
# import pandas as pd
# rawData = pd.read_excel('BQ_SCHMA.xlsx')

# %%
# for i in rawData.columns:
#     print(i)
# sch=[]
# for i in rawData['Schema']:
#     sch.append(i)
# sch

# %%
DF
# Out:
#    branchCode         branchName     brandName Hour   invoiceNumber  \
# 0          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6013
# 1          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6014
# 2          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6015
# 3          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6016
# 4          IN   Indira Nagar DDN  Burger Singh   12    SIN2122-6017
# ..        ...                ...           ...  ...             ...
# 19        MVD  Mayur Vihar Delhi  Burger Singh   00  KZMVD2122-1989
# 0         MVD  Mayur Vihar Delhi  Burger Singh   00  KZMVD2122-1990
# 1         MVD  Mayur Vihar Delhi  Burger Singh   01  KZMVD2122-1991
# 2         MVD  Mayur Vihar Delhi  Burger Singh   01  KZMVD2122-1992
# 3         MVD  Mayur Vihar Delhi  Burger Singh   02  KZMVD2122-1993
#
#    orderNumber                invoiceDate                createdDate  \
# 0          NaN  2021-11-18T12:05:47+05:30  2021-11-18T12:05:47+05:30
# 1          NaN  2021-11-18T12:08:09+05:30  2021-11-18T12:08:09+05:30
# 2          NaN  2021-11-18T12:19:56+05:30  2021-11-18T12:19:56+05:30
# 3          NaN  2021-11-18T12:20:53+05:30  2021-11-18T12:20:53+05:30
# 4          NaN  2021-11-18T12:24:45+05:30  2021-11-18T12:24:45+05:30
# ..         ...                        ...                        ...
# 19         NaN  2021-11-19T00:40:43+05:30  2021-11-19T00:40:43+05:30
# 0          NaN  2021-11-19T00:50:48+05:30  2021-11-19T00:50:48+05:30
# 1          NaN  2021-11-19T01:21:21+05:30  2021-11-19T01:21:21+05:30
# 2          NaN  2021-11-19T01:49:10+05:30  2021-11-19T01:49:10+05:30
# 3          NaN  2021-11-19T02:56:04+05:30  2021-11-19T02:56:04+05:30
#
#                  modifiedDate deviceLabel  ... customer.email  \
# 0   2021-11-18T12:27:44+05:30         NaN  ...            NaN
# 1   2021-11-18T12:46:19+05:30         NaN  ...            NaN
# 2   2021-11-18T12:48:17+05:30         NaN  ...            NaN
# 3   2021-11-18T12:55:00+05:30         NaN  ...            NaN
# 4   2021-11-18T13:09:29+05:30         NaN  ...            NaN
# ..                        ...         ...  ...            ...
# 19  2021-11-19T00:44:35+05:30         NaN  ...            NaN
# 0   2021-11-19T01:26:39+05:30         NaN  ...            NaN
# 1   2021-11-19T01:45:37+05:30         NaN  ...            NaN
# 2   2021-11-19T02:08:37+05:30         NaN  ...            NaN
# 3   2021-11-19T03:16:03+05:30         NaN  ...            NaN
#
#    customer.phoneNumber customer.taxId            statusInfo.reason  \
# 0                   NaN            NaN                          NaN
# 1                   NaN            NaN                          NaN
# 2                   NaN            NaN                          NaN
# 3                   NaN            NaN                          NaN
# 4                   NaN            NaN                          NaN
# ..                  ...            ...                          ...
# 19                  NaN            NaN  Cancelled by zomato. reject
# 0                   NaN            NaN                          NaN
# 1                   NaN            NaN                          NaN
# 2                   NaN            NaN                          NaN
# 3                   NaN            NaN                          NaN
#
#                                    statusInfo.remarks resourceInfo.resourceId  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# ..                                                ...                     ...
# 19  Accepted 4 minutes ago. Cancelled by zomato. r...                     NaN
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
#
#    resourceInfo.resourceName resourceInfo.groupSize  \
# 0                       5426                    NaN
# 1                       3256                    NaN
# 2                       7833                    NaN
# 3                       9449                    NaN
# 4                       9231                    NaN
# ..                       ...                    ...
# 19                      1673                    NaN
# 0                       2203                    NaN
# 1                       9861                    NaN
# 2                       7146                    NaN
# 3                       7573                    NaN
#
#    resourceInfo.resourceGroupName delivery.paymentMode
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# ..                            ...                  ...
# 19                            NaN                  NaN
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
#
# [5346 rows x 91 columns]

# %%
col=['Date', 'Time', 'Hour', 'Business_Date', 'Month','Bill_Number','Reference_Number','City', 'Outlet_Name', 'Waiter_Name', 'Order_Status', 'Order_Type', 'Order_Source','Preorder','Preorder_Delivery_Time','Table_No',
 'Payment_Mode', 'Subtotal', 'Offer_Code', 'Discount_Type', 'Discount_Rate', 'Restaurant_Discount', 'Loyalty_Amount',
 'PACKAGING_CHARGES', 'DELIVERY_CHARGE', 'PACKAGING_CHARGES_RS_20', 'CGST_25', 'PACKING_CHARGES', 'SGST_25',
 'SERVICE_CHARGE', 'SGST', 'PACKAGING_CHARGE', 'CGST', 'GST', 'Grand_Total', 'Round_Off', 'Net_Payable', 'Amount_Paid',
 'Order_Comment', 'Cancellation_Reason', 'No_of_persons', 'Pax_Validity', 'Delivery_Source', 'Delivery_Boy', 'Delivery_Time',
 'Customer_Mobile_No','Mobile_no_Validity', 'Customer_Name', 'Customer_Email', 'Customer_Address', 'Locality', 'Complementary', 'On_Cart_Discount', 'Offers_Promocode',
 'Discounted_By', 'Discount_Reason', 'Sales_Bucket', 'Post_Tax_Restaurant_Discount', 'Post_Tax_Source_Discount', 'Coalese']
bqd = pd.DataFrame(columns=col)
bqd
# Out:
# Empty DataFrame
# Columns: [Date, Time, Hour, Business_Date, Month, Bill_Number, Reference_Number, City, Outlet_Name, Waiter_Name, Order_Status, Order_Type, Order_Source, Preorder, Preorder_Delivery_Time, Table_No, Payment_Mode, Subtotal, Offer_Code, Discount_Type, Discount_Rate, Restaurant_Discount, Loyalty_Amount, PACKAGING_CHARGES, DELIVERY_CHARGE, PACKAGING_CHARGES_RS_20, CGST_25, PACKING_CHARGES, SGST_25, SERVICE_CHARGE, SGST, PACKAGING_CHARGE, CGST, GST, Grand_Total, Round_Off, Net_Payable, Amount_Paid, Order_Comment, Cancellation_Reason, No_of_persons, Pax_Validity, Delivery_Source, Delivery_Boy, Delivery_Time, Customer_Mobile_No, Mobile_no_Validity, Customer_Name, Customer_Email, Customer_Address, Locality, Complementary, On_Cart_Discount, Offers_Promocode, Discounted_By, Discount_Reason, Sales_Bucket, Post_Tax_Restaurant_Discount, Post_Tax_Source_Discount, Coalese]
# Index: []
#
# [0 rows x 60 columns]

# %%
# v.str[0:19]
bqd['Date']= DF['createdDate'].str[0:10] + "T00:00:00"
bqd['Time'] = "1970-01-01T"  + DF['createdDate'].str[11:19]
bqd['Hour'] = DF['Hour']
bqd['Business_Date'] = DATE +"T00:00:00"
# bqd['Month'] = DF['invoiceDate_month']
bqd['Bill_Number'] = DF['invoiceNumber']
bqd['Reference_Number'] = DF['sourceInfo.invoiceNumber']
bqd['City'] = DF['delivery.address.city']
bqd['Outlet_Name'] = DF['branchName']
bqd['Payment_Mode'] = DF['sourceInfo.source']
# bqd['Subtotal'] = DF['billAmount']
bqd['Restaurant_Discount'] = DF['totalDiscountAmount']
bqd['PACKAGING_CHARGES'] = DF['netChargeAmount']
bqd['DELIVERY_CHARGE'] = DF['chargeAmount']
bqd['PACKING_CHARGES'] = DF['netChargeAmount']
bqd['CGST'] = DF['taxAmount']
bqd['Net_Payable'] = DF['itemTotalAmount']
bqd['Amount_Paid'] = DF['totalAmount']
bqd['Order_Comment'] = DF['note']
bqd['Cancellation_Reason'] = DF['statusInfo.reason']
bqd['No_of_persons'] = DF['itemCount']
bqd['Delivery_Source'] = DF['sourceInfo.source']
bqd['Delivery_Boy'] = DF['deliveryBy.name']
bqd['Customer_Mobile_No'] = DF['customer.phoneNumber']
bqd['Customer_Name'] = DF['delivery.name']
bqd['Customer_Email'] = DF['customer.email']
bqd['Customer_Address'] = DF['delivery.address.addressLine']
bqd['Order_Comment'] = DF['note']

# %%
bins=[0,100,150,200,250,300,350,400,450,500,550,600,650,700,75000]
labels=['Below 100',
        'Between 100-150',
        'Between 150-200',
        'Between 200-250',
        'Between 250-300',
        'Between 300-350',
        'Between 350-400', 
        'Between 400-450',
        'Between 450-500',
        'Between 500-550',
        'Between 550-600',
        'Between 600-650',
        'Between Than 650-700',
        'More Than 700']
bqd['Sales_Bucket'] = pd.cut(bqd['Net_Payable'], bins, labels=labels)

# bqd['Sales_Bucket']

# %%
bqd
# Out:
#                    Date                 Time Hour        Business_Date Month  \
# 0   2021-11-18T00:00:00  1970-01-01T12:05:47   12  2021-11-18T00:00:00   NaN
# 1   2021-11-18T00:00:00  1970-01-01T12:08:09   12  2021-11-18T00:00:00   NaN
# 2   2021-11-18T00:00:00  1970-01-01T12:19:56   12  2021-11-18T00:00:00   NaN
# 3   2021-11-18T00:00:00  1970-01-01T12:20:53   12  2021-11-18T00:00:00   NaN
# 4   2021-11-18T00:00:00  1970-01-01T12:24:45   12  2021-11-18T00:00:00   NaN
# ..                  ...                  ...  ...                  ...   ...
# 19  2021-11-19T00:00:00  1970-01-01T00:40:43   00  2021-11-18T00:00:00   NaN
# 0   2021-11-19T00:00:00  1970-01-01T00:50:48   00  2021-11-18T00:00:00   NaN
# 1   2021-11-19T00:00:00  1970-01-01T01:21:21   01  2021-11-18T00:00:00   NaN
# 2   2021-11-19T00:00:00  1970-01-01T01:49:10   01  2021-11-18T00:00:00   NaN
# 3   2021-11-19T00:00:00  1970-01-01T02:56:04   02  2021-11-18T00:00:00   NaN
#
#        Bill_Number Reference_Number       City        Outlet_Name Waiter_Name  \
# 0     SIN2122-6013     120292545426        NaN   Indira Nagar DDN         NaN
# 1     SIN2122-6014       3614713256   Dehradun   Indira Nagar DDN         NaN
# 2     SIN2122-6015       3317827833   Dehradun   Indira Nagar DDN         NaN
# 3     SIN2122-6016       3483879449   Dehradun   Indira Nagar DDN         NaN
# 4     SIN2122-6017       3782429231   Dehradun   Indira Nagar DDN         NaN
# ..             ...              ...        ...                ...         ...
# 19  KZMVD2122-1989       3057361673  Delhi NCR  Mayur Vihar Delhi         NaN
# 0   KZMVD2122-1990     120338422203        NaN  Mayur Vihar Delhi         NaN
# 1   KZMVD2122-1991       3840329861  Delhi NCR  Mayur Vihar Delhi         NaN
# 2   KZMVD2122-1992       2733937146  Delhi NCR  Mayur Vihar Delhi         NaN
# 3   KZMVD2122-1993       3008217573  Delhi NCR  Mayur Vihar Delhi         NaN
#
#     ... Locality Complementary On_Cart_Discount Offers_Promocode  \
# 0   ...      NaN           NaN              NaN              NaN
# 1   ...      NaN           NaN              NaN              NaN
# 2   ...      NaN           NaN              NaN              NaN
# 3   ...      NaN           NaN              NaN              NaN
# 4   ...      NaN           NaN              NaN              NaN
# ..  ...      ...           ...              ...              ...
# 19  ...      NaN           NaN              NaN              NaN
# 0   ...      NaN           NaN              NaN              NaN
# 1   ...      NaN           NaN              NaN              NaN
# 2   ...      NaN           NaN              NaN              NaN
# 3   ...      NaN           NaN              NaN              NaN
#
#    Discounted_By Discount_Reason     Sales_Bucket  \
# 0            NaN             NaN        Below 100
# 1            NaN             NaN  Between 250-300
# 2            NaN             NaN  Between 150-200
# 3            NaN             NaN  Between 350-400
# 4            NaN             NaN  Between 350-400
# ..           ...             ...              ...
# 19           NaN             NaN  Between 250-300
# 0            NaN             NaN        Below 100
# 1            NaN             NaN  Between 150-200
# 2            NaN             NaN  Between 250-300
# 3            NaN             NaN  Between 200-250
#
#    Post_Tax_Restaurant_Discount Post_Tax_Source_Discount Coalese
# 0                           NaN                      NaN     NaN
# 1                           NaN                      NaN     NaN
# 2                           NaN                      NaN     NaN
# 3                           NaN                      NaN     NaN
# 4                           NaN                      NaN     NaN
# ..                          ...                      ...     ...
# 19                          NaN                      NaN     NaN
# 0                           NaN                      NaN     NaN
# 1                           NaN                      NaN     NaN
# 2                           NaN                      NaN     NaN
# 3                           NaN                      NaN     NaN
#
# [5346 rows x 60 columns]

# %%
# bqd.to_excel('bdd.xlsx', index=False)
# bqd.to_csv('bdd.csv', index=False)

# %%
import pandas as pd
import gspread
import gspread_dataframe as gd
from gspread_dataframe import set_with_dataframe


gc = gspread.service_account(filename='universalsolder.json')
# sh = gc.open_by_key('1hwqYXSi7vMHvHHZcJ2ru3T8sxkpiAy1Tlxry_FgGDzk')#sales_summary
sh = gc.open_by_key('1H7nPcdsUrUikFUYktyltuHHfMqFLGqKViQV4fOFNyKE')#sales_page

worksheet = sh.get_worksheet(0) #-> 0 - first sheet, 1 - second sheet etc. 
set_with_dataframe(worksheet, bqd)
print('************************* COMPLETE *****************************')
# Out:
# ************************* COMPLETE *****************************
